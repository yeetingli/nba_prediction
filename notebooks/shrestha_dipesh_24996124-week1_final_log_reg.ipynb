# %% [markdown]
# # Experiment: Week 1 Logistic Regression

# %% [markdown]
# ### Import required Packages

# %%
# install custom package 
# !pip install pip install -i https://test.pypi.org/simple/ group_12_krml_adv_mla_2024

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns=300
pd.options.display.max_rows=300

# %%
# Loading the data
train_df = pd.read_csv('../data/raw/train.csv', low_memory=False)
test_df = pd.read_csv('../data/raw/test.csv', low_memory=False)

# %% [markdown]
# ## Data Exploration

# %%
# first 5 entries of train_df
train_df.head()
# Out:
#             team conf  GP  Min_per   Ortg   usg   eFG  TS_per  ORB_per  \
# 0  South Alabama   SB  26     29.5   97.3  16.6  42.5   44.43      1.6
# 1       Utah St.  WAC  34     60.9  108.3  14.9  52.4   54.48      3.8
# 2  South Florida   BE  27     72.0   96.2  21.8  45.7   47.98      2.1
# 3     Pepperdine  WCC  30     44.5   97.7  16.0  53.6   53.69      4.1
# 4        Pacific   BW  33     56.2   96.5  22.0  52.8   54.31      8.3
#
#    DRB_per  AST_per  TO_per  FTM  FTA  FT_per  twoPM  twoPA  twoP_per  TPM  \
# 0      4.6     15.8    16.3   10   14   0.714     26     68     0.382   13
# 1      6.3     13.6    19.8   30   45   0.667     56    113     0.496   20
# 2      8.0     14.7    15.9   45   67   0.672     67    157     0.427   50
# 3      9.4     13.7    23.8   14   27   0.519     25     63     0.397   28
# 4     18.6      8.2    22.7   64  114   0.561     93    176     0.528    0
#
#    TPA  TP_per  blk_per  stl_per   ftr  yr     ht  num    porpag     adjoe  \
# ...

# %%
# shape of training data
train_df.shape
# Out:
# (46618, 64)

# %%
# Counting the nan values
nan_count = train_df.isna().sum()
nan_percentage = (train_df.isna().sum()/len(train_df))*100

nan_data = pd.DataFrame(
    {
        'Feature': nan_count.index,
        'NaN_Count': nan_count.values,
        'NaN_Percentage': nan_percentage.values
    }
)

# Filter out features with zero NaN values
nan_data = nan_data[nan_data['NaN_Count']>0]
nan_data = nan_data.sort_values(by='NaN_Count', ascending=False)

# %%
nan_data
# Out:
#                 Feature  NaN_Count  NaN_Percentage
# 43                 pick      45411       97.410871
# 32             Rec_Rank      32281       69.245785
# 42          dunks_ratio      26218       56.240079
# 39            mid_ratio       8568       18.379167
# 38            rim_ratio       8499       18.231155
# 41  dunksmiss_dunksmade       5758       12.351452
# 36              midmade       5758       12.351452
# 35      rimmade_rimmiss       5758       12.351452
# 34              rimmade       5758       12.351452
# 37      midmade_midmiss       5758       12.351452
# 40            dunksmade       5758       12.351452
# 26                  num       4679       10.036896
# 33              ast_tov       3467        7.437041
# 24                   yr        292        0.626367
# 25                   ht         64        0.137286
# 44                 drtg         42        0.090094
# 45                adrtg         42        0.090094
# ...

# %%
# feature information
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 64 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   team                 46618 non-null  object
#  1   conf                 46618 non-null  object
#  2   GP                   46618 non-null  int64
#  3   Min_per              46618 non-null  float64
#  4   Ortg                 46618 non-null  float64
#  5   usg                  46618 non-null  float64
#  6   eFG                  46618 non-null  float64
#  7   TS_per               46618 non-null  float64
#  8   ORB_per              46618 non-null  float64
#  9   DRB_per              46618 non-null  float64
#  10  AST_per              46618 non-null  float64
#  11  TO_per               46618 non-null  float64
#  12  FTM                  46618 non-null  int64
#  13  FTA                  46618 non-null  int64
#  14  FT_per               46618 non-null  float64
# ...

# %%
# Features statistics
train_df.describe().T
# Out:
#                        count         mean        std          min  \
# GP                   46618.0    23.542988  10.076829     1.000000
# Min_per              46618.0    37.339013  28.019801     0.000000
# Ortg                 46618.0    91.784360  30.235568     0.000000
# usg                  46618.0    18.164578   6.181982     0.000000
# eFG                  46618.0    44.424392  18.026404     0.000000
# TS_per               46618.0    47.571397  17.217909     0.000000
# ORB_per              46618.0     5.654071   9.985025     0.000000
# DRB_per              46618.0    12.575102  11.041089     0.000000
# AST_per              46618.0    10.923008   9.430012     0.000000
# TO_per               46618.0    20.535915  12.210669     0.000000
# FTM                  46618.0    33.357909  37.306108     0.000000
# FTA                  46618.0    47.887597  50.190318     0.000000
# FT_per               46618.0     0.579193   0.266445     0.000000
# ...

# %% [markdown]
# ##### Remarks:
# - Most of features have Q3 very small then the maximum values

# %%
target_counts = train_df["drafted"].value_counts()
target_counts.plot(kind="bar", color=['orange', 'blue'])
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, '0.0'), Text(1, 0, '1.0')])

# %% [markdown]
# The provided data is highly imbalanced.

# %%
# Get all the related columns

# categorical columns
cat_cols = train_df.select_dtypes(include=['object','category']).columns.to_list()
# numerical columns
num_cols = train_df.select_dtypes(include=['int64', 'float64']).columns.to_list()

print(f'categorical columns : {cat_cols}')
print(f'numerical columns: {num_cols}')
# Out:
# categorical columns : ['team', 'conf', 'yr', 'ht', 'num', 'type', 'player_id']
# numerical columns: ['GP', 'Min_per', 'Ortg', 'usg', 'eFG', 'TS_per', 'ORB_per', 'DRB_per', 'AST_per', 'TO_per', 'FTM', 'FTA', 'FT_per', 'twoPM', 'twoPA', 'twoP_per', 'TPM', 'TPA', 'TP_per', 'blk_per', 'stl_per', 'ftr', 'porpag', 'adjoe', 'pfr', 'year', 'Rec_Rank', 'ast_tov', 'rimmade', 'rimmade_rimmiss', 'midmade', 'midmade_midmiss', 'rim_ratio', 'mid_ratio', 'dunksmade', 'dunksmiss_dunksmade', 'dunks_ratio', 'pick', 'drtg', 'adrtg', 'dporpag', 'stops', 'bpm', 'obpm', 'dbpm', 'gbpm', 'mp', 'ogbpm', 'dgbpm', 'oreb', 'dreb', 'treb', 'ast', 'stl', 'blk', 'pts', 'drafted']

# %%
# Copy train_df
df_copy = train_df.copy()

# %%
# unique values in category columns
for col in cat_cols:
    print(f'{col}: {len(df_copy[col].unique())}')
# Out:
# team: 355
# conf: 36
# yr: 8
# ht: 39
# num: 81
# type: 1
# player_id: 20377

# %%
df_copy[cat_cols].describe().T
# Out:
#            count unique                                   top   freq
# team       46618    355                                  Army    176
# conf       46618     36                                   A10   1880
# yr         46326      7                                    Jr  12401
# ht         46554     38                                 7-Jun   4615
# num        41939     80                                   1.0   1743
# type       46618      1                                   all  46618
# player_id  46618  20377  2336a719-c648-440c-821d-32fb0d9760bf      6

# %% [markdown]
# #####  Remarks:
# - type feature has only one value. This single value provide no significant effect on the training process. Thus it will be removed.
# - yr feature should have 4 unique values, this would be resolved.
# - player_id and num feature would be more specific, rather the model has to behave for general.

# %% [markdown]
# #### Droping features all categorical features
# Features team and conf have very high number of variables, when lable encoding it might cause few feature to get more importance than others. So removing it would be a better option.
#
# Similarly features type, num and player_id are specific features that has capacity to hinder the model to learn and may hamper due to overfiting. And height ht has value in month and day format.

# %%
# Drop categorical features
df_copy.drop(columns=cat_cols, inplace=True)

# %% [markdown]
# ### Feature Transformation

# %%
# performance variable which have 3rd quartile very less than upper bound and first quartile very greater than 
performance_var = ['Ortg', 'eFG', 'TS_per', 'ORB_per', 'DRB_per', 'AST_per','TO_per', 
                   'FTM','FTA','twoPM', 'twoPA', 'TPM', 'TPA', 'TP_per', 'blk_per', 'stl_per', 
                   'ftr', 'adjoe','porpag','pfr','ast_tov', 'rimmade', 'rimmade_rimmiss', 
                   'midmade', 'midmade_midmiss','dunksmade', 'dunksmiss_dunksmade', 'drtg',
                   'adrtg','stops', 'bpm', 'obpm', 'dbpm', 'gbpm', 'mp', 'ogbpm','dgbpm']


processor = []
def iqr_clipper(data,col, q1=0.25, q3=0.75):

    Q1 = data[col].quantile(q1)
    Q3 = data[col].quantile(q3)

    IQR = Q3-Q1

    lower_bound = Q1-1.5*IQR
    upper_bound = Q3+1.5*IQR
    
    data[col] = data[col].apply(lambda x: max(lower_bound, min(x, upper_bound)))

    processor.append({col:[{"lower_bound":lower_bound, "upper_bound":upper_bound}]})
    return data

# %%
for col in performance_var:
    df_copy = iqr_clipper(df_copy, col)

# %% [markdown]
# #### Handling NAN values in num cols

# %%
# Filling missing values with 0
df_copy.fillna(0, inplace=True)

# %% [markdown]
# ### Correlation of Features with target variables

# %%
import seaborn as sns

num_cols = df_copy.select_dtypes(include=['int64', 'float64', 'bool']).columns.to_list()

plt.figure(figsize=(8, 16))
sns.heatmap(df_copy[num_cols].corr()[['drafted']], annot=True, cmap='coolwarm', vmin=-1, vmax=1)
# plt.title(f'Correlation with {target_column}')
plt.show()

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

y = df_copy['drafted']
# Define the feature matrix (X) by dropping the 'drafted' column from df_copy_cleaned
X = df_copy.drop('drafted', axis=1)
# X_copy = X.drop(columns=['pick'])
# Scaling the value
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Baseline Modeling and Evaluation

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, \
                            precision_score, recall_score, classification_report

from sklearn.linear_model import LogisticRegression

import matplotlib.pyplot as plt
import numpy as np

def train_and_evaluate_model(X, y, model, kf):
    """
    Train and evaluate the model using Stratified K-Fold Cross-Validation.

    Args:
        X: Features matrix.
        y: Target vector.
        model: The machine learning model to train.
        kf: StratifiedKFold instance for cross-validation.

    Returns:
        A dictionary containing ROC AUC scores, precision scores, recall scores,
        confusion matrices, and classification reports for each fold.
    """
    # Lists to store results
    results = {
        'roc_auc_scores': [],
        'precision_scores': [],
        'recall_scores': [],
        'confusion_matrices': [],
        'classification_reports': []
    }
    

    for fold, (train_index, val_index) in enumerate(kf.split(X, y), 1):
        X_train, X_val = X[train_index], X[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        # Train the model
        model.fit(X_train, y_train)
        
        # Predict probability scores for the positive class
        y_prob = model.predict_proba(X_val)[:, 1]
        # Predictions for confusion matrix, precision, and recall
        y_pred = model.predict(X_val)  

        # Compute ROC AUC score
        score = roc_auc_score(y_val, y_prob)
        results['roc_auc_scores'].append(score)

        # Compute confusion matrix, precision, recall, and classification report
        cm = confusion_matrix(y_val, y_pred)
        precision = precision_score(y_val, y_pred)
        recall = recall_score(y_val, y_pred)
        report = classification_report(y_val, y_pred, output_dict=True)

        # Store metrics
        results['confusion_matrices'].append(cm)
        results['precision_scores'].append(precision)
        results['recall_scores'].append(recall)
        results['classification_reports'].append(report)

        # Plot ROC curve
        fpr, tpr, _ = roc_curve(y_val, y_prob)
        plt.plot(fpr, tpr, alpha=0.3, label=f'ROC fold {fold} (area = {auc(fpr, tpr):.2f})')

    return results

def plot_roc_curve():
    """
    Plot the ROC curve across all folds.
    """
    plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='navy', alpha=0.8)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve Across All Folds')
    plt.legend(loc='lower right')
    plt.show()

def print_evaluation_summary(results):
    """
    Print the evaluation summary including ROC AUC, precision, recall,
    confusion matrices, and classification reports.

    Args:
        results: A dictionary containing evaluation metrics for each fold.
    """
    mean_roc_auc = np.mean(results['roc_auc_scores'])
    std_roc_auc = np.std(results['roc_auc_scores'])
    mean_precision = np.mean(results['precision_scores'])
    std_precision = np.std(results['precision_scores'])
    mean_recall = np.mean(results['recall_scores'])
    std_recall = np.std(results['recall_scores'])

    print(f"Mean ROC AUC Score from Cross-Validation: {mean_roc_auc:.4f}")
    print(f"Standard Deviation of ROC AUC Scores: {std_roc_auc:.4f}")
    print(f"Mean Precision Score from Cross-Validation: {mean_precision:.4f}")
    print(f"Standard Deviation of Precision Scores: {std_precision:.4f}")
    print(f"Mean Recall Score from Cross-Validation: {mean_recall:.4f}")
    print(f"Standard Deviation of Recall Scores: {std_recall:.4f}\n")

    for fold, (cm, report) in enumerate(zip(results['confusion_matrices'], results['classification_reports']), 1):
        print(f"Confusion Matrix for fold {fold}:\n{cm}\n")
        # print(f"Classification Report for fold {fold}:\n{classification_report(report)}\n")


def plot_confusion_matrix_from_results(results):
    """
    Plot confusion matrices from the results of cross-validation.

    Args:
        results: A dictionary containing confusion matrices for each fold.
    """
    for fold, cm in enumerate(results['confusion_matrices'], 1):
        disp = ConfusionMatrixDisplay(confusion_matrix=cm)
        disp.plot(cmap=plt.cm.Blues)
        plt.title(f'Confusion Matrix for Fold {fold}')
        plt.show()


def plot_feature_importance(model, X):
    """
    Plot feature importances of the trained model.

    Args:
        model: The trained machine learning model.
        X: Features matrix.
    """
    # Get feature importances
    feature_importances = model.feature_importances_
    feature_names = X.columns if hasattr(X, 'columns') else np.arange(X.shape[1])
    
    # Create a DataFrame for feature importances
    importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
    importance_df = importance_df.sort_values(by='Importance', ascending=False)

    # Plot feature importances
    plt.figure(figsize=(10, 6))
    plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
    plt.xlabel('Importance')
    plt.title('Feature Importances')
    plt.gca().invert_yaxis()  
    plt.show()

# Initialize Stratified K-Folds
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Initialize the LogisticRegression model
log_model = LogisticRegression(max_iter=100)

# Train and evaluate the model
results = train_and_evaluate_model(X_scaled, y, log_model, kf)

# Plot ROC curve
plot_roc_curve()

# Print evaluation summary
print_evaluation_summary(results)


# Call the function to plot confusion matrices from the results
plot_confusion_matrix_from_results(results)
# Out:
# Mean ROC AUC Score from Cross-Validation: 0.9950
# Standard Deviation of ROC AUC Scores: 0.0023
# Mean Precision Score from Cross-Validation: 0.6444
# Standard Deviation of Precision Scores: 0.0542
# Mean Recall Score from Cross-Validation: 0.4889
# Standard Deviation of Recall Scores: 0.0492
#
# Confusion Matrix for fold 1:
# [[4602   16]
#  [  24   20]]
#
# Confusion Matrix for fold 2:
# [[4605   13]
#  [  22   22]]
#
# Confusion Matrix for fold 3:
# [[4604   14]
#  [  25   19]]
#
# Confusion Matrix for fold 4:
# [[4607   11]
#  [  21   23]]
#
# Confusion Matrix for fold 5:
# [[4606   11]
#  [  22   23]]
#
# Confusion Matrix for fold 6:
# [[4610    7]
#  [  25   20]]
#
# Confusion Matrix for fold 7:
# [[4607   10]
#  [  26   19]]
#
# Confusion Matrix for fold 8:
# [[4603   14]
#  [  23   22]]
#
# Confusion Matrix for fold 9:
# [[4603   14]
#  [  21   23]]
#
# Confusion Matrix for fold 10:
# [[4606   11]
#  [  18   26]]

# %% [markdown]
# ### Testing

# %%
test_df_copy = test_df.copy()


# keep the player id separate
player_id = test_df_copy['player_id']
# drop all the category columns for test_df_copy
test_df_copy.drop(columns=cat_cols, inplace=True)


# using the same threshold as in training data
for entry in processor:
    for key, values in entry.items():
        test_df_copy[key].apply(lambda x: max(values[0]['lower_bound'], min(x,values[0]['upper_bound'] )))


# fill NA with Zero
test_df_copy.fillna(0, inplace=True)

# standardize the test df
scaled_test_df = scaler.transform(test_df_copy)

# make prediction
y_test_prob = log_model.predict_proba(scaled_test_df)[:, 1]

# storing the prediction in dataframe
results_df = pd.DataFrame({'player_id':player_id, 'drafted':y_test_prob})

results_df.head(5)
# Out:
#                               player_id       drafted
# 0  23549e01-c1b3-4ca0-a0fd-de9b5d76276b  9.032346e-08
# 1  52a518bb-b34a-4b43-adee-5e996cb853fa  4.500588e-08
# 2  ad3d9117-b6bf-4675-ab97-3497acf3e555  8.901039e-05
# 3  eaf66a5c-6f4c-4070-bc70-a99d731b3740  2.006462e-05
# 4  55d07491-5bd1-447f-844e-9cb36eaa442e  1.077806e-03

# %%
## CSV generation for Kaggle submission
# results_df.to_csv('../data/results/shrestha_dipesh_24996124-week1_final-LogisticRegressionwithStratifiedCV.csv', index=False)

# %% [markdown]
# ### Tuning Hyperparameters with Regularization

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV

def tune_hyperparameters(model, param_grid, X, y):
    """
    Tune hyperparameters using GridSearchCV.

    Args:
        X: Features matrix.
        y: Target vector.

    Returns:
        The best model found by GridSearchCV.
    """
    # 5 fold stratifiedkfold
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    #  GridSearchCV
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=skf,
                               scoring='roc_auc', verbose=1, n_jobs=-1)

    # Fit GridSearchCV
    grid_search.fit(X, y)

    # Print the best parameters and score
    print(f"Best Parameters: {grid_search.best_params_}")
    print(f"Best ROC AUC Score: {grid_search.best_score_:.4f}")

    # Return the best model
    return grid_search.best_estimator_

# %%
param_grid = [
    # For lasso Regression
    {'penalty': ['l1'], 'C': [0.01, 0.1, 1, 10, 100], 'solver': ['liblinear']},
    # For Ridge Regression
    {'penalty': ['l2'], 'C': [0.01, 0.1, 1, 10, 100], 'solver': ['lbfgs', 'saga']}
]

best_model = tune_hyperparameters(log_model, param_grid, X_scaled, y)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# Best Parameters: {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
# Best ROC AUC Score: 0.9952

# %%
# Initialize the XGBoost model
# xgb_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc', seed=42)

# Train and evaluate the model
results = train_and_evaluate_model(X_scaled, y, best_model, kf)

# Plot ROC curve
plot_roc_curve()

# Print evaluation summary
print_evaluation_summary(results)

# Plot feature importances
# plot_feature_importance(best_model, X)
# Out:
# Mean ROC AUC Score from Cross-Validation: 0.9952
# Standard Deviation of ROC AUC Scores: 0.0014
# Mean Precision Score from Cross-Validation: 0.6421
# Standard Deviation of Precision Scores: 0.0620
# Mean Recall Score from Cross-Validation: 0.4236
# Standard Deviation of Recall Scores: 0.0525
#
# Confusion Matrix for fold 1:
# [[4607   11]
#  [  26   18]]
#
# Confusion Matrix for fold 2:
# [[4605   13]
#  [  25   19]]
#
# Confusion Matrix for fold 3:
# [[4607   11]
#  [  27   17]]
#
# Confusion Matrix for fold 4:
# [[4611    7]
#  [  24   20]]
#
# Confusion Matrix for fold 5:
# [[4606   11]
#  [  24   21]]
#
# Confusion Matrix for fold 6:
# [[4611    6]
#  [  26   19]]
#
# Confusion Matrix for fold 7:
# [[4607   10]
#  [  31   14]]
#
# Confusion Matrix for fold 8:
# [[4607   10]
#  [  27   18]]
#
# Confusion Matrix for fold 9:
# [[4602   15]
#  [  25   19]]
#
# Confusion Matrix for fold 10:
# [[4605   12]
#  [  21   23]]

# %%
# Call the function to plot confusion matrices from the results
plot_confusion_matrix_from_results(results)

# %%
def plot_regularized_feature_importance(model, X):
    """
    Plot feature importance for regularized logistic regression models.
    
    Args:
        model: Trained logistic regression model with regularization.
        X: Features DataFrame.
        model_name: Name of the model (Lasso, Ridge, ElasticNet).
    """
       # Get absolute values of the coefficients for importance
    feature_importances = np.abs(model.coef_[0])
    
    # Get the feature names from the DataFrame
    feature_names = X.columns if hasattr(X, 'columns') else np.arange(X.shape[1])

    # Create a DataFrame for feature importance
    importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': feature_importances
    })
    
    # Sort the features by importance
    importance_df = importance_df.sort_values(by='Importance', ascending=False)

    # Print the feature importance list
    print(f"\nFeature Importance for Logistic Regression:")
    print(importance_df)
    
    # Plot the feature importance
    plt.figure(figsize=(10, 10))
    plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
    plt.xlabel('Coefficient Magnitude (Importance)')
    plt.title(f'Feature Importance in  Logistic Regression')
    plt.gca().invert_yaxis()  # Most important feature at the top
    plt.show()

# Train regularized models and plot feature importance
plot_regularized_feature_importance(log_model, X )
# Out:
# Feature Importance for Logistic Regression:
#                 Feature  Importance
# 43                 obpm    1.589893
# 9                TO_per    1.270549
# 1               Min_per    1.133727
# 8               AST_per    1.101748
# 55                  pts    1.010778
# 40              dporpag    0.926047
# 39                adrtg    0.914535
# 52                  ast    0.891919
# 23                adjoe    0.719880
# 42                  bpm    0.582472
# 38                 drtg    0.512117
# 12               FT_per    0.504895
# 49                 oreb    0.503784
# 26             Rec_Rank    0.475829
# 5                TS_per    0.468132
# 35  dunksmiss_dunksmade    0.457830
# 15             twoP_per    0.453778
# 37                 pick    0.429279
# 44                 dbpm    0.419917
# 6               ORB_per    0.413361
# 27              ast_tov    0.402870
# 34            dunksmade    0.402728
# 46                   mp    0.396415
# 0                    GP    0.346942
# ...

# %% [markdown]
# ### Testing
# Using test data for model testing

# %%
# Predicting with bestmodel obtained as lasso regression
y_test_pred_prob = best_model.predict_proba(scaled_test_df)[:, 1]

# Result for DataFrame 
results_df = pd.DataFrame({'player_id':test_df['player_id'], 'drafted':y_test_pred_prob})
results_df.head(5)

## CSV generation for Kaggle submission
# results_df.to_csv('../data/results/shrestha_dipesh_24996124_week1_final-Hyperparameter_Tuned-LogReg.csv', index=False)
# Out:
#                               player_id       drafted
# 0  23549e01-c1b3-4ca0-a0fd-de9b5d76276b  5.273328e-06
# 1  52a518bb-b34a-4b43-adee-5e996cb853fa  8.956965e-07
# 2  ad3d9117-b6bf-4675-ab97-3497acf3e555  2.072199e-04
# 3  eaf66a5c-6f4c-4070-bc70-a99d731b3740  3.199175e-05
# 4  55d07491-5bd1-447f-844e-9cb36eaa442e  5.385737e-03
