# %% [markdown]
# ## Data Exploration and Cleaning

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/raw/train.csv')
# Out:
# C:\Users\bert_\AppData\Local\Temp\ipykernel_5488\4229903785.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw/train.csv')

# %%
df.head()
# Out:
#             team conf  GP  Min_per   Ortg   usg   eFG  TS_per  ORB_per  \
# 0  South Alabama   SB  26     29.5   97.3  16.6  42.5   44.43      1.6
# 1       Utah St.  WAC  34     60.9  108.3  14.9  52.4   54.48      3.8
# 2  South Florida   BE  27     72.0   96.2  21.8  45.7   47.98      2.1
# 3     Pepperdine  WCC  30     44.5   97.7  16.0  53.6   53.69      4.1
# 4        Pacific   BW  33     56.2   96.5  22.0  52.8   54.31      8.3
#
#    DRB_per  ...     dgbpm    oreb    dreb    treb     ast     stl     blk  \
# 0      4.6  ... -1.941150  0.1923  0.6154  0.8077  1.1923  0.3462  0.0385
# 1      6.3  ... -0.247934  0.6765  1.2647  1.9412  1.8235  0.4118  0.2353
# 2      8.0  ... -0.883163  0.6296  2.3333  2.9630  1.9630  0.4815  0.0000
# 3      9.4  ... -0.393459  0.7000  1.4333  2.1333  1.1000  0.5667  0.1333
# 4     18.6  ... -0.668318  1.4242  3.3030  4.7273  0.8485  0.4545  0.3333
#
#        pts                             player_id  drafted
# ...

# %%
pd.options.display.max_columns=300
pd.options.display.max_rows=300

# %%
df.shape
# Out:
# (46618, 64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 64 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   team                 46618 non-null  object
#  1   conf                 46618 non-null  object
#  2   GP                   46618 non-null  int64
#  3   Min_per              46618 non-null  float64
#  4   Ortg                 46618 non-null  float64
#  5   usg                  46618 non-null  float64
#  6   eFG                  46618 non-null  float64
#  7   TS_per               46618 non-null  float64
#  8   ORB_per              46618 non-null  float64
#  9   DRB_per              46618 non-null  float64
#  10  AST_per              46618 non-null  float64
#  11  TO_per               46618 non-null  float64
#  12  FTM                  46618 non-null  int64
#  13  FTA                  46618 non-null  int64
#  14  FT_per               46618 non-null  float64
# ...

# %%
df.describe(include='all')
# Out:
#          team   conf            GP       Min_per          Ortg           usg  \
# count   46618  46618  46618.000000  46618.000000  46618.000000  46618.000000
# unique    355     36           NaN           NaN           NaN           NaN
# top      Army    A10           NaN           NaN           NaN           NaN
# freq      176   1880           NaN           NaN           NaN           NaN
# mean      NaN    NaN     23.542988     37.339013     91.784360     18.164578
# std       NaN    NaN     10.076829     28.019801     30.235568      6.181982
# min       NaN    NaN      1.000000      0.000000      0.000000      0.000000
# 25%       NaN    NaN     17.000000      9.600000     83.900000     14.600000
# 50%       NaN    NaN     28.000000     35.900000     97.000000     18.100000
# 75%       NaN    NaN     31.000000     62.200000    106.800000     21.800000
# max       NaN    NaN     41.000000     98.000000    834.000000     50.000000
#
# ...

# %%
df.isna().sum()
# Out:
# team                       0
# conf                       0
# GP                         0
# Min_per                    0
# Ortg                       0
# usg                        0
# eFG                        0
# TS_per                     0
# ORB_per                    0
# DRB_per                    0
# AST_per                    0
# TO_per                     0
# FTM                        0
# FTA                        0
# FT_per                     0
# twoPM                      0
# twoPA                      0
# twoP_per                   0
# TPM                        0
# TPA                        0
# TP_per                     0
# blk_per                    0
# stl_per                    0
# ftr                        0
# yr                       292
# ht                        64
# num                     4679
# porpag                     0
# adjoe                      0
# pfr                        0
# year                       0
# type                       0
# ...

# %%
df_clean = df.copy()

# %%
threshold = 0.2 * len(df)

# %%
columns_to_drop = df.columns[df.isnull().sum() > threshold]

# %%
df_clean = df_clean.drop(columns=columns_to_drop)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 61 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   team                 46618 non-null  object
#  1   conf                 46618 non-null  object
#  2   GP                   46618 non-null  int64
#  3   Min_per              46618 non-null  float64
#  4   Ortg                 46618 non-null  float64
#  5   usg                  46618 non-null  float64
#  6   eFG                  46618 non-null  float64
#  7   TS_per               46618 non-null  float64
#  8   ORB_per              46618 non-null  float64
#  9   DRB_per              46618 non-null  float64
#  10  AST_per              46618 non-null  float64
#  11  TO_per               46618 non-null  float64
#  12  FTM                  46618 non-null  int64
#  13  FTA                  46618 non-null  int64
#  14  FT_per               46618 non-null  float64
# ...

# %%
num_cols = df_clean.select_dtypes(include=['float64', 'int64']).columns
for col in num_cols:
    df_clean[col] = df_clean[col].fillna(df_clean[col].median())

# %%
cat_cols = df_clean.select_dtypes(include=['object']).columns

# %%
df_clean[cat_cols].head()
# Out:
#             team conf  yr     ht  num type  \
# 0  South Alabama   SB  So  2-Jun  NaN  all
# 1       Utah St.  WAC  So  4-Jun  NaN  all
# 2  South Florida   BE  Sr  4-Jun  NaN  all
# 3     Pepperdine  WCC  Sr  4-Jun  NaN  all
# 4        Pacific   BW  Sr  8-Jun  NaN  all
#
#                               player_id
# 0  b2716b2d-3422-4959-9fe7-fe496414a4e8
# 1  bb387960-e3a0-4ffd-96ae-184bad07cb8a
# 2  89bbdf11-eadd-4de4-95e5-03f7e2874aa1
# 3  0c87ada8-8446-4ea2-a05b-bd07aed5f37a
# 4  84661e00-ad20-4308-817e-efa8da52a86c

# %%
df_clean[cat_cols].describe()
# Out:
#          team   conf     yr     ht      num   type  \
# count   46618  46618  46326  46554  41939.0  46618
# unique    355     36      7     38     80.0      1
# top      Army    A10     Jr  7-Jun      1.0    all
# freq      176   1880  12401   4615   1743.0  46618
#
#                                    player_id
# count                                  46618
# unique                                 20377
# top     2336a719-c648-440c-821d-32fb0d9760bf
# freq                                       6

# %%
df_clean = df_clean.drop(columns=cat_cols)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 54 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GP                   46618 non-null  int64
#  1   Min_per              46618 non-null  float64
#  2   Ortg                 46618 non-null  float64
#  3   usg                  46618 non-null  float64
#  4   eFG                  46618 non-null  float64
#  5   TS_per               46618 non-null  float64
#  6   ORB_per              46618 non-null  float64
#  7   DRB_per              46618 non-null  float64
#  8   AST_per              46618 non-null  float64
#  9   TO_per               46618 non-null  float64
#  10  FTM                  46618 non-null  int64
#  11  FTA                  46618 non-null  int64
#  12  FT_per               46618 non-null  float64
#  13  twoPM                46618 non-null  int64
#  14  twoPA                46618 non-null  int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 16))
sns.heatmap(df_clean[num_cols].corr()[['drafted']], annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()

# %%
import seaborn as sns

corr_matrix = df_clean.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Matrix Heatmap')
plt.figure(figsize=(20, 15))
plt.show()

# %% [markdown]
# Remove highly correlated features

# %%
correlation_matrix = df_clean.corr().abs()

upper_tri = correlation_matrix.where(
    np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool)
)

threshold = 0.9

to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > threshold)]

df_clean = df_clean.drop(columns=to_drop)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 40 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GP         46618 non-null  int64
#  1   Min_per    46618 non-null  float64
#  2   Ortg       46618 non-null  float64
#  3   usg        46618 non-null  float64
#  4   eFG        46618 non-null  float64
#  5   ORB_per    46618 non-null  float64
#  6   DRB_per    46618 non-null  float64
#  7   AST_per    46618 non-null  float64
#  8   TO_per     46618 non-null  float64
#  9   FTM        46618 non-null  int64
#  10  FT_per     46618 non-null  float64
#  11  twoPM      46618 non-null  int64
#  12  twoP_per   46618 non-null  float64
#  13  TPM        46618 non-null  int64
#  14  TP_per     46618 non-null  float64
#  15  blk_per    46618 non-null  float64
#  16  stl_per    46618 non-null  float64
#  17  ftr        46618 non-null  float64
#  18  porpag     46618 non-null  float64
# ...

# %%
df_cleaned = df_clean.copy()

# %% [markdown]
# ## Assess Baseline

# %%
! pip install -i https://test.pypi.org/simple/ group_12_krml_adv_mla_2024==2024.0.1.7
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...
#   Using cached https://test-files.pythonhosted.org/packages/6f/11/08a0065893e9fa18ff65f980bb05b45b82bfa361e99df5e50159a682d07a/group_12_krml_adv_mla_2024-2024.0.1.7-py3-none-any.whl.metadata (1.1 kB)
# ...
# Using cached https://test-files.pythonhosted.org/packages/6f/11/08a0065893e9fa18ff65f980bb05b45b82bfa361e99df5e50159a682d07a/group_12_krml_adv_mla_2024-2024.0.1.7-py3-none-any.whl (6.2 kB)
# ...
#   Attempting uninstall: group_12_krml_adv_mla_2024
#     Found existing installation: group_12_krml_adv_mla_2024 2024.0.2.1
#     Uninstalling group_12_krml_adv_mla_2024-2024.0.2.1:
#       Successfully uninstalled group_12_krml_adv_mla_2024-2024.0.2.1
# ...

# %%
y = df_cleaned.pop('drafted')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
df_scaled = scaler.fit_transform(df_cleaned)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test,  y_train, y_test = train_test_split(df_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %%
from group_12_krml_adv_mla_2024.models.null import NullClassifier

# %%
base_model = NullClassifier()

# %%
y_base = base_model.fit_predict(y_train)

# %%
from group_12_krml_adv_mla_2024.models.performance import print_classifier_scores

print_classifier_scores(y_preds=y_base, y_actuals=y_train, average="weighted", set_name='Training')
# Out:
# Accuracy Training: 0.990481042526948
# F1 Score Training: 0.9857443247586095

# %%
print_classifier_scores(y_preds=base_model.predict(y_test), y_actuals=y_test, average="weighted", set_name='Testing')
# Out:
# Accuracy Testing: 0.9904547404547405
# F1 Score Testing: 0.9857049979093192

# %% [markdown]
# ## Initial Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb_classifier = GradientBoostingClassifier(n_estimators=100, random_state=42)

# %%
gb_classifier.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_train_preds = gb_classifier.predict(X_train)
y_val_preds = gb_classifier.predict(X_test)

# %%
from group_12_krml_adv_mla_2024.models.performance import print_classifier_outcomes
print_classifier_outcomes(y_val_preds, y_test, average="weighted")
# Out:
# Accuracy: 0.9904547404547405
# F1 Score: 0.9886545091337905
# Confusion Matrix:
# [[9215   20]
#  [  69   20]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      9235
#          1.0       0.50      0.22      0.31        89
#
#     accuracy                           0.99      9324
#    macro avg       0.75      0.61      0.65      9324
# weighted avg       0.99      0.99      0.99      9324

# %%
print_classifier_scores(y_preds=y_train_preds, y_actuals=y_train, average="weighted", set_name='Training')
# Out:
# Accuracy Training: 0.9948785327398509
# F1 Score Training: 0.9943670378112011

# %%
print_classifier_scores(y_preds=y_val_preds, y_actuals=y_test, average="weighted", set_name='Testing')
# Out:
# Accuracy Testing: 0.9904547404547405
# F1 Score Testing: 0.9886545091337905

# %%
from group_12_krml_adv_mla_2024.models.performance import compute_roc_curve

fpr, tpr, roc_auc = compute_roc_curve(gb_classifier, X_test, y_test, positive_class=1)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# ROC AUC Score: 0.9721

# %% [markdown]
# ## Trying different Feature removals

# %% [markdown]
# Feature Importance

# %%
importances = gb_classifier.feature_importances_

# %%
feature_names = df_cleaned.columns

feature_importances = pd.DataFrame({
    'feature': feature_names,
    'importance': importances
})

feature_importances = feature_importances.sort_values(by='importance', ascending=False)

top_features = feature_importances.head(10)

# %%
print(top_features)
# Out:
#       feature  importance
# 28    dporpag    0.195612
# 32       gbpm    0.087623
# 11      twoPM    0.083880
# 26  dunksmade    0.070341
# 18     porpag    0.068555
# 30       obpm    0.045486
# 29        bpm    0.041003
# 12   twoP_per    0.037253
# 27       drtg    0.032057
# 22    rimmade    0.031845

# %%
top_feature_names = top_features['feature'].tolist()

df_featureimportance = df_cleaned[top_feature_names]

# %%
dffi_scaled = scaler.fit_transform(df_featureimportance)

X_trains, X_tests,  y_trains, y_tests = train_test_split(dffi_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %%
gb_classifier.fit(X_trains, y_trains)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_train_preds = gb_classifier.predict(X_trains)
y_val_preds = gb_classifier.predict(X_tests)

# %%
print_classifier_outcomes(y_val_preds, y_tests, average="weighted")
# Out:
# Accuracy: 0.9900257400257401
# F1 Score: 0.9882491227553963
# Confusion Matrix:
# [[9212   23]
#  [  70   19]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      9235
#          1.0       0.45      0.21      0.29        89
#
#     accuracy                           0.99      9324
#    macro avg       0.72      0.61      0.64      9324
# weighted avg       0.99      0.99      0.99      9324

# %%
print_classifier_scores(y_preds=y_train_preds, y_actuals=y_trains, average="weighted", set_name='Training')
# Out:
# Accuracy Training: 0.9940741137984662
# F1 Score Training: 0.9933964722092622

# %%
print_classifier_scores(y_preds=y_val_preds, y_actuals=y_tests, average="weighted", set_name='Testing')
# Out:
# Accuracy Testing: 0.9900257400257401
# F1 Score Testing: 0.9882491227553963

# %%
fpr, tpr, roc_auc = compute_roc_curve(gb_classifier, X_tests, y_tests, positive_class=1)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# ROC AUC Score: 0.9752

# %% [markdown]
# RFE

# %%
from sklearn.feature_selection import RFE

rfe = RFE(estimator=gb_classifier, n_features_to_select=10)  # Select top 10 features
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=GradientBoostingClassifier(random_state=42),
#     n_features_to_select=10)

# %%
selected_features = df_cleaned.columns[rfe.support_]

# %%
print(selected_features)
# Out:
# Index(['twoPM', 'twoP_per', 'porpag', 'dunksmade', 'drtg', 'dporpag', 'bpm',
#        'obpm', 'gbpm', 'blk'],
#       dtype='object')

# %%
df_rfe = df_cleaned[selected_features]

# %%
dfrfe_scaled = scaler.fit_transform(df_rfe)

X_trained, X_tested,  y_trained, y_tested = train_test_split(dfrfe_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %%
gb_classifier.fit(X_trained, y_trained)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_train_preds = gb_classifier.predict(X_trained)
y_val_preds = gb_classifier.predict(X_tested)

# %%
print_classifier_outcomes(y_val_preds, y_tested, average="weighted")
# Out:
# Accuracy: 0.9901329901329902
# F1 Score: 0.9884259949068761
# Confusion Matrix:
# [[9212   23]
#  [  69   20]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      9235
#          1.0       0.47      0.22      0.30        89
#
#     accuracy                           0.99      9324
#    macro avg       0.73      0.61      0.65      9324
# weighted avg       0.99      0.99      0.99      9324

# %%
print_classifier_scores(y_preds=y_train_preds, y_actuals=y_trained, average="weighted", set_name='Training')
# Out:
# Accuracy Training: 0.9939132300101893
# F1 Score Training: 0.993280577545689

# %%
print_classifier_scores(y_preds=y_val_preds, y_actuals=y_tested, average="weighted", set_name='Testing')
# Out:
# Accuracy Testing: 0.9901329901329902
# F1 Score Testing: 0.9884259949068761

# %%
fpr, tpr, roc_auc = compute_roc_curve(gb_classifier, X_tested, y_tested, positive_class=1)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# ROC AUC Score: 0.9761

# %%
from sklearn.feature_selection import RFE

rfe = RFE(estimator=gb_classifier, n_features_to_select=20)  # Select top 20 features
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=GradientBoostingClassifier(random_state=42),
#     n_features_to_select=20)

# %%
selected_features = df_cleaned.columns[rfe.support_]

# %%
print(selected_features)
# Out:
# Index(['GP', 'Min_per', 'AST_per', 'TO_per', 'twoPM', 'twoP_per', 'TPM',
#        'porpag', 'ast_tov', 'rimmade', 'midmade', 'dunksmade', 'drtg',
#        'dporpag', 'bpm', 'obpm', 'gbpm', 'oreb', 'dreb', 'blk'],
#       dtype='object')

# %%
df_rfe = df_cleaned[selected_features]

# %%
dfrfe_scaled = scaler.fit_transform(df_rfe)

X_trained, X_tested,  y_trained, y_tested = train_test_split(dfrfe_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %%
gb_classifier.fit(X_trained, y_trained)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_train_preds = gb_classifier.predict(X_trained)
y_val_preds = gb_classifier.predict(X_tested)

# %%
print_classifier_outcomes(y_val_preds, y_tested, average="weighted")
# Out:
# Accuracy: 0.9906692406692407
# F1 Score: 0.9891020677793849
# Confusion Matrix:
# [[9214   21]
#  [  66   23]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      9235
#          1.0       0.52      0.26      0.35        89
#
#     accuracy                           0.99      9324
#    macro avg       0.76      0.63      0.67      9324
# weighted avg       0.99      0.99      0.99      9324

# %%
print_classifier_scores(y_preds=y_train_preds, y_actuals=y_trained, average="weighted", set_name='Training')
# Out:
# Accuracy Training: 0.9947444629162868
# F1 Score Training: 0.99413789938263

# %%
print_classifier_scores(y_preds=y_val_preds, y_actuals=y_tested, average="weighted", set_name='Testing')
# Out:
# Accuracy Testing: 0.9906692406692407
# F1 Score Testing: 0.9891020677793849

# %%
fpr, tpr, roc_auc = compute_roc_curve(gb_classifier, X_tested, y_tested, positive_class=1)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# ROC AUC Score: 0.9772

# %% [markdown]
#  ### PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=10)  # Reduce to 10 components
X_train_pca = pca.fit_transform(X_train)

# %%
X_test_pca = pca.transform(X_test)

# %%
gb_classifier.fit(X_train_pca, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_train_preds = gb_classifier.predict(X_train_pca)
y_val_preds = gb_classifier.predict(X_test_pca)

# %%
print_classifier_outcomes(y_val_preds, y_test, average="weighted")
# Out:
# Accuracy: 0.9907764907764908
# F1 Score: 0.9891808213259932
# Confusion Matrix:
# [[9215   20]
#  [  66   23]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      9235
#          1.0       0.53      0.26      0.35        89
#
#     accuracy                           0.99      9324
#    macro avg       0.76      0.63      0.67      9324
# weighted avg       0.99      0.99      0.99      9324

# %%
print_classifier_scores(y_preds=y_train_preds, y_actuals=y_train, average="weighted", set_name='Training')
# Out:
# Accuracy Training: 0.994261811551456
# F1 Score Training: 0.9933230112970598

# %%
print_classifier_scores(y_preds=y_val_preds, y_actuals=y_test, average="weighted", set_name='Testing')
# Out:
# Accuracy Testing: 0.9907764907764908
# F1 Score Testing: 0.9891808213259932

# %%
fpr, tpr, roc_auc = compute_roc_curve(gb_classifier, X_test_pca, y_test, positive_class=1)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# ROC AUC Score: 0.9588

# %% [markdown]
# ## Grid Search using stratified Kfold for Hyperparamater Tuning

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold

gbgs = GradientBoostingClassifier(random_state=42)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

# %%
grid_search = GridSearchCV(
    estimator=gbgs,
    param_grid=param_grid,
    scoring='roc_auc',  # Optimize for ROC AUC
    cv=skf,             # Use StratifiedKFold for cross-validation
    n_jobs=-1,          # Use all available CPU cores
    verbose=2           # Verbosity level
)

# %%
grid_search.fit(X_trained, y_trained)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=GradientBoostingClassifier(random_state=42), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 4, 5], 'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='roc_auc', verbose=2)

# %%
print("Best hyperparameters:", grid_search.best_params_)
print("Best ROC AUC score:", grid_search.best_score_)
# Out:
# Best hyperparameters: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# Best ROC AUC score: 0.9809888234095195

# %% [markdown]
# ## Gradient Boost with GridSearch Hyperparameters

# %%
gbf = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=10, random_state=42)

# %%
gbf.fit(X_trained,y_trained)
# Out:
# GradientBoostingClassifier(min_samples_leaf=4, min_samples_split=10,
#                            random_state=42)

# %%
y_train_preds = gbf.predict(X_trained)
y_val_preds = gbf.predict(X_tested)

# %%
print_classifier_outcomes(y_val_preds, y_tested, average="weighted")
# Out:
# Accuracy: 0.9904547404547405
# F1 Score: 0.9888515406018996
# Confusion Matrix:
# [[9213   22]
#  [  67   22]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      9235
#          1.0       0.50      0.25      0.33        89
#
#     accuracy                           0.99      9324
#    macro avg       0.75      0.62      0.66      9324
# weighted avg       0.99      0.99      0.99      9324

# %%
print_classifier_scores(y_preds=y_train_preds, y_actuals=y_trained, average="weighted", set_name='Training')
# Out:
# Accuracy Training: 0.9949857885987022
# F1 Score Training: 0.9944439462338804

# %%
print_classifier_scores(y_preds=y_val_preds, y_actuals=y_tested, average="weighted", set_name='Testing')
# Out:
# Accuracy Testing: 0.9904547404547405
# F1 Score Testing: 0.9888515406018996

# %%
fpr, tpr, roc_auc = compute_roc_curve(gbf, X_tested, y_tested, positive_class=1)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# ROC AUC Score: 0.9712

# %% [markdown]
# ## Run on Test set and Produce CSV for Kaggle

# %%
test_df = pd.read_csv('../data/raw/test.csv')

# %%
test_df.isna().sum()
# Out:
# team                      0
# conf                      0
# GP                        0
# Min_per                   0
# Ortg                      0
# usg                       0
# eFG                       0
# TS_per                    0
# ORB_per                   0
# DRB_per                   0
# AST_per                   0
# TO_per                    0
# FTM                       0
# FTA                       0
# FT_per                    0
# twoPM                     0
# twoPA                     0
# twoP_per                  0
# TPM                       0
# TPA                       0
# TP_per                    0
# blk_per                   0
# stl_per                   0
# ftr                       0
# yr                        2
# ht                       13
# num                      96
# porpag                    0
# adjoe                     0
# pfr                       0
# year                      0
# type                      0
# Rec_Rank               3536
# ...

# %%
test_df = test_df.drop(columns=columns_to_drop)
test_df = test_df.drop(columns=to_drop)
test_df = test_df.drop(columns=cat_cols)

# %%
n_cols = df_cleaned.select_dtypes(include=['float64', 'int64']).columns

if 'drafted' in n_cols:
    n_cols = n_cols.drop('drafted')

for col in n_cols:
    median_value = df_cleaned[col].median()
    test_df[col] = test_df[col].fillna(median_value)

# %%
test_df = test_df[selected_features]

# %%
scaled_test_df = scaler.fit_transform(test_df)

# %%
y_test_prob = gbf.predict_proba(scaled_test_df)[:,1]

# %%
t_df = pd.read_csv('../data/raw/test.csv')
results_df = pd.DataFrame({'player_id':t_df['player_id'], 'drafted':y_test_prob})

# %%
results_df.to_csv('../data/external/GBClassifier.csv', index=False)
