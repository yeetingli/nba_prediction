# %% [markdown]
# ## Data Exploration and Cleaning

# %%
import pandas as pd
import numpy as np

# %%
! pip install -i https://test.pypi.org/simple/ group_12_krml_adv_mla_2024==2024.0.2.1
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: group_12_krml_adv_mla_2024==2024.0.2.1 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (2024.0.2.1)
# Requirement already satisfied: pandas==2.2.2 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from group_12_krml_adv_mla_2024==2024.0.2.1) (2.2.2)
# Requirement already satisfied: scikit-learn==1.5.1 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from group_12_krml_adv_mla_2024==2024.0.2.1) (1.5.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from pandas==2.2.2->group_12_krml_adv_mla_2024==2024.0.2.1) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from pandas==2.2.2->group_12_krml_adv_mla_2024==2024.0.2.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from pandas==2.2.2->group_12_krml_adv_mla_2024==2024.0.2.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from pandas==2.2.2->group_12_krml_adv_mla_2024==2024.0.2.1) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from scikit-learn==1.5.1->group_12_krml_adv_mla_2024==2024.0.2.1) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from scikit-learn==1.5.1->group_12_krml_adv_mla_2024==2024.0.2.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from scikit-learn==1.5.1->group_12_krml_adv_mla_2024==2024.0.2.1) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.2->group_12_krml_adv_mla_2024==2024.0.2.1) (1.16.0)

# %%
df = pd.read_csv('../data/raw/train.csv')
# Out:
# C:\Users\bert_\AppData\Local\Temp\ipykernel_15188\4229903785.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw/train.csv')

# %%
df.head()
# Out:
#             team conf  GP  Min_per   Ortg   usg   eFG  TS_per  ORB_per  \
# 0  South Alabama   SB  26     29.5   97.3  16.6  42.5   44.43      1.6
# 1       Utah St.  WAC  34     60.9  108.3  14.9  52.4   54.48      3.8
# 2  South Florida   BE  27     72.0   96.2  21.8  45.7   47.98      2.1
# 3     Pepperdine  WCC  30     44.5   97.7  16.0  53.6   53.69      4.1
# 4        Pacific   BW  33     56.2   96.5  22.0  52.8   54.31      8.3
#
#    DRB_per  ...     dgbpm    oreb    dreb    treb     ast     stl     blk  \
# 0      4.6  ... -1.941150  0.1923  0.6154  0.8077  1.1923  0.3462  0.0385
# 1      6.3  ... -0.247934  0.6765  1.2647  1.9412  1.8235  0.4118  0.2353
# 2      8.0  ... -0.883163  0.6296  2.3333  2.9630  1.9630  0.4815  0.0000
# 3      9.4  ... -0.393459  0.7000  1.4333  2.1333  1.1000  0.5667  0.1333
# 4     18.6  ... -0.668318  1.4242  3.3030  4.7273  0.8485  0.4545  0.3333
#
#        pts                             player_id  drafted
# 0   3.8846  b2716b2d-3422-4959-9fe7-fe496414a4e8      0.0
# 1   5.9412  bb387960-e3a0-4ffd-96ae-184bad07cb8a      0.0
# 2  12.1852  89bbdf11-eadd-4de4-95e5-03f7e2874aa1      0.0
# 3   4.9333  0c87ada8-8446-4ea2-a05b-bd07aed5f37a      0.0
# 4   7.5758  84661e00-ad20-4308-817e-efa8da52a86c      0.0
#
# [5 rows x 64 columns]

# %%
pd.options.display.max_columns=300
pd.options.display.max_rows=300

# %%
df.shape
# Out:
# (46618, 64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 64 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   team                 46618 non-null  object
#  1   conf                 46618 non-null  object
#  2   GP                   46618 non-null  int64
#  3   Min_per              46618 non-null  float64
#  4   Ortg                 46618 non-null  float64
#  5   usg                  46618 non-null  float64
#  6   eFG                  46618 non-null  float64
#  7   TS_per               46618 non-null  float64
#  8   ORB_per              46618 non-null  float64
#  9   DRB_per              46618 non-null  float64
#  10  AST_per              46618 non-null  float64
#  11  TO_per               46618 non-null  float64
#  12  FTM                  46618 non-null  int64
#  13  FTA                  46618 non-null  int64
#  14  FT_per               46618 non-null  float64
#  15  twoPM                46618 non-null  int64
#  16  twoPA                46618 non-null  int64
#  17  twoP_per             46618 non-null  float64
#  18  TPM                  46618 non-null  int64
#  19  TPA                  46618 non-null  int64
#  20  TP_per               46618 non-null  float64
#  21  blk_per              46618 non-null  float64
#  22  stl_per              46618 non-null  float64
#  23  ftr                  46618 non-null  float64
#  24  yr                   46326 non-null  object
#  25  ht                   46554 non-null  object
#  26  num                  41939 non-null  object
#  27  porpag               46618 non-null  float64
#  28  adjoe                46618 non-null  float64
#  29  pfr                  46618 non-null  float64
#  30  year                 46618 non-null  int64
#  31  type                 46618 non-null  object
#  32  Rec_Rank             14337 non-null  float64
#  33  ast_tov              43151 non-null  float64
#  34  rimmade              40860 non-null  float64
#  35  rimmade_rimmiss      40860 non-null  float64
#  36  midmade              40860 non-null  float64
#  37  midmade_midmiss      40860 non-null  float64
#  38  rim_ratio            38119 non-null  float64
#  39  mid_ratio            38050 non-null  float64
#  40  dunksmade            40860 non-null  float64
#  41  dunksmiss_dunksmade  40860 non-null  float64
#  42  dunks_ratio          20400 non-null  float64
#  43  pick                 1207 non-null   float64
#  44  drtg                 46576 non-null  float64
#  45  adrtg                46576 non-null  float64
#  46  dporpag              46576 non-null  float64
#  47  stops                46576 non-null  float64
#  48  bpm                  46576 non-null  float64
#  49  obpm                 46576 non-null  float64
#  50  dbpm                 46576 non-null  float64
#  51  gbpm                 46576 non-null  float64
#  52  mp                   46582 non-null  float64
#  53  ogbpm                46576 non-null  float64
#  54  dgbpm                46576 non-null  float64
#  55  oreb                 46582 non-null  float64
#  56  dreb                 46582 non-null  float64
#  57  treb                 46582 non-null  float64
#  58  ast                  46582 non-null  float64
#  59  stl                  46582 non-null  float64
#  60  blk                  46582 non-null  float64
#  61  pts                  46582 non-null  float64
#  62  player_id            46618 non-null  object
#  63  drafted              46618 non-null  float64
# dtypes: float64(49), int64(8), object(7)
# memory usage: 22.8+ MB

# %%
df.describe(include='all')
# Out:
#          team   conf            GP       Min_per          Ortg           usg  \
# count   46618  46618  46618.000000  46618.000000  46618.000000  46618.000000
# unique    355     36           NaN           NaN           NaN           NaN
# top      Army    A10           NaN           NaN           NaN           NaN
# freq      176   1880           NaN           NaN           NaN           NaN
# mean      NaN    NaN     23.542988     37.339013     91.784360     18.164578
# std       NaN    NaN     10.076829     28.019801     30.235568      6.181982
# min       NaN    NaN      1.000000      0.000000      0.000000      0.000000
# 25%       NaN    NaN     17.000000      9.600000     83.900000     14.600000
# 50%       NaN    NaN     28.000000     35.900000     97.000000     18.100000
# 75%       NaN    NaN     31.000000     62.200000    106.800000     21.800000
# max       NaN    NaN     41.000000     98.000000    834.000000     50.000000
#
#                  eFG        TS_per       ORB_per       DRB_per       AST_per  \
# count   46618.000000  46618.000000  46618.000000  46618.000000  46618.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       44.424392     47.571397      5.654071     12.575102     10.923008
# std        18.026404     17.217909      9.985025     11.041089      9.430012
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%
# mean                                     NaN      0.009524
# std                                      NaN      0.097127
# min                                      NaN      0.000000
# 25%                                      NaN      0.000000
# 50%                                      NaN      0.000000
# 75%                                      NaN      0.000000
# max                                      NaN      1.000000

# %%
df.isna().sum()
# Out:
# team                       0
# conf                       0
# GP                         0
# Min_per                    0
# Ortg                       0
# usg                        0
# eFG                        0
# TS_per                     0
# ORB_per                    0
# DRB_per                    0
# AST_per                    0
# TO_per                     0
# FTM                        0
# FTA                        0
# FT_per                     0
# twoPM                      0
# twoPA                      0
# twoP_per                   0
# TPM                        0
# TPA                        0
# TP_per                     0
# blk_per                    0
# stl_per                    0
# ftr                        0
# yr                       292
# ht                        64
# num                     4679
# porpag                     0
# adjoe                      0
# pfr                        0
# year                       0
# type                       0
# Rec_Rank               32281
# ast_tov                 3467
# rimmade                 5758
# rimmade_rimmiss         5758
# midmade                 5758
# midmade_midmiss         5758
# rim_ratio               8499
# mid_ratio               8568
# dunksmade               5758
# dunksmiss_dunksmade     5758
# dunks_ratio            26218
# pick                   45411
# drtg                      42
# adrtg                     42
# dporpag                   42
# stops                     42
# bpm                       42
# obpm                      42
# dbpm                      42
# gbpm                      42
# mp                        36
# ogbpm                     42
# dgbpm                     42
# oreb                      36
# dreb                      36
# treb                      36
# ast                       36
# stl                       36
# blk                       36
# pts                       36
# player_id                  0
# drafted                    0
# dtype: int64

# %%
df_clean = df.copy()

# %%
threshold = 0.2 * len(df)

# %%
columns_to_drop = df.columns[df.isnull().sum() > threshold]

# %%
df_clean = df_clean.drop(columns=columns_to_drop)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 61 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   team                 46618 non-null  object
#  1   conf                 46618 non-null  object
#  2   GP                   46618 non-null  int64
#  3   Min_per              46618 non-null  float64
#  4   Ortg                 46618 non-null  float64
#  5   usg                  46618 non-null  float64
#  6   eFG                  46618 non-null  float64
#  7   TS_per               46618 non-null  float64
#  8   ORB_per              46618 non-null  float64
#  9   DRB_per              46618 non-null  float64
#  10  AST_per              46618 non-null  float64
#  11  TO_per               46618 non-null  float64
#  12  FTM                  46618 non-null  int64
#  13  FTA                  46618 non-null  int64
#  14  FT_per               46618 non-null  float64
#  15  twoPM                46618 non-null  int64
#  16  twoPA                46618 non-null  int64
#  17  twoP_per             46618 non-null  float64
#  18  TPM                  46618 non-null  int64
#  19  TPA                  46618 non-null  int64
#  20  TP_per               46618 non-null  float64
#  21  blk_per              46618 non-null  float64
#  22  stl_per              46618 non-null  float64
#  23  ftr                  46618 non-null  float64
#  24  yr                   46326 non-null  object
#  25  ht                   46554 non-null  object
#  26  num                  41939 non-null  object
#  27  porpag               46618 non-null  float64
#  28  adjoe                46618 non-null  float64
#  29  pfr                  46618 non-null  float64
#  30  year                 46618 non-null  int64
#  31  type                 46618 non-null  object
#  32  ast_tov              43151 non-null  float64
#  33  rimmade              40860 non-null  float64
#  34  rimmade_rimmiss      40860 non-null  float64
#  35  midmade              40860 non-null  float64
#  36  midmade_midmiss      40860 non-null  float64
#  37  rim_ratio            38119 non-null  float64
#  38  mid_ratio            38050 non-null  float64
#  39  dunksmade            40860 non-null  float64
#  40  dunksmiss_dunksmade  40860 non-null  float64
#  41  drtg                 46576 non-null  float64
#  42  adrtg                46576 non-null  float64
#  43  dporpag              46576 non-null  float64
#  44  stops                46576 non-null  float64
#  45  bpm                  46576 non-null  float64
#  46  obpm                 46576 non-null  float64
#  47  dbpm                 46576 non-null  float64
#  48  gbpm                 46576 non-null  float64
#  49  mp                   46582 non-null  float64
#  50  ogbpm                46576 non-null  float64
#  51  dgbpm                46576 non-null  float64
#  52  oreb                 46582 non-null  float64
#  53  dreb                 46582 non-null  float64
#  54  treb                 46582 non-null  float64
#  55  ast                  46582 non-null  float64
#  56  stl                  46582 non-null  float64
#  57  blk                  46582 non-null  float64
#  58  pts                  46582 non-null  float64
#  59  player_id            46618 non-null  object
#  60  drafted              46618 non-null  float64
# dtypes: float64(46), int64(8), object(7)
# memory usage: 21.7+ MB

# %%
num_cols = df_clean.select_dtypes(include=['float64', 'int64']).columns

# %%
cat_cols = df_clean.select_dtypes(include=['object']).columns

# %%
df_clean[cat_cols].head()
# Out:
#             team conf  yr     ht  num type  \
# 0  South Alabama   SB  So  2-Jun  NaN  all
# 1       Utah St.  WAC  So  4-Jun  NaN  all
# 2  South Florida   BE  Sr  4-Jun  NaN  all
# 3     Pepperdine  WCC  Sr  4-Jun  NaN  all
# 4        Pacific   BW  Sr  8-Jun  NaN  all
#
#                               player_id
# 0  b2716b2d-3422-4959-9fe7-fe496414a4e8
# 1  bb387960-e3a0-4ffd-96ae-184bad07cb8a
# 2  89bbdf11-eadd-4de4-95e5-03f7e2874aa1
# 3  0c87ada8-8446-4ea2-a05b-bd07aed5f37a
# 4  84661e00-ad20-4308-817e-efa8da52a86c

# %%
df_clean[cat_cols].describe()
# Out:
#          team   conf     yr     ht      num   type  \
# count   46618  46618  46326  46554  41939.0  46618
# unique    355     36      7     38     80.0      1
# top      Army    A10     Jr  7-Jun      1.0    all
# freq      176   1880  12401   4615   1743.0  46618
#
#                                    player_id
# count                                  46618
# unique                                 20377
# top     2336a719-c648-440c-821d-32fb0d9760bf
# freq                                       6

# %%
df_clean['yr'].value_counts()
# Out:
# yr
# Jr      12401
# Fr      12312
# So      10979
# Sr      10627
# 0           5
# 57.1        1
# 42.9        1
# Name: count, dtype: int64

# %%
df_clean['ht'].value_counts()
# Out:
# ht
# 7-Jun     4615
# 8-Jun     4557
# 4-Jun     4414
# 5-Jun     4362
# 6-Jun     4276
# 3-Jun     4230
# 2-Jun     3884
# 9-Jun     3290
# 1-Jun     2979
# Jun-00    2530
# 10-Jun    2041
# 11-May    1307
# 10-May    1196
# 11-Jun     900
# Jul-00     538
# 9-May      522
# -          241
# 8-May      208
# 1-Jul      165
# 7-May       84
# 2-Jul       71
# 6-May       32
# 3-Jul       30
# Apr-00      20
# 0           19
# 5-May        8
# 4-Jul        8
# 6-Jul        6
# 5-Jul        4
# 4-May        4
# 3-May        3
# Jr           2
# 1-May        2
# 2-May        2
# So           1
# Fr           1
# 6'4          1
# 5-Apr        1
# Name: count, dtype: int64

# %%
columns_to_keep = ['yr', 'ht']
cat_columns_to_drop = [col for col in cat_cols if col not in columns_to_keep]
df_clean = df_clean.drop(columns=cat_columns_to_drop)

# %%
df_clean['yr'] = df_clean['yr'].replace(['57.1', '42.9'], 'Fr') #Replace to lowest level Fr
df_clean['yr'].value_counts()
# Out:
# yr
# Jr    12401
# Fr    12314
# So    10979
# Sr    10627
# 0         5
# Name: count, dtype: int64

# %%
year_mapping = {'Fr': 1, 'So': 2, 'Jr': 3, 'Sr': 4}
df_clean['yr'] = df_clean['yr'].map(year_mapping)
df_clean['yr'].value_counts()
# Out:
# yr
# 3.0    12401
# 1.0    12314
# 2.0    10979
# 4.0    10627
# Name: count, dtype: int64

# %%
from group_12_krml_adv_mla_2024.features.feature_engineering import convert_height

# %%
df_clean = convert_height(df_clean, 'ht')

# %%
df_clean['ht'].value_counts()
# Out:
# ht
# 200.66    4615
# 203.20    4557
# 193.04    4414
# 195.58    4362
# 198.12    4276
# 190.50    4230
# 187.96    3884
# 205.74    3290
# 185.42    2979
# 182.88    2530
# 208.28    2041
# 180.34    1307
# 177.80    1196
# 210.82     900
# 213.36     538
# 175.26     522
# 172.72     208
# 215.90     165
# 170.18      84
# 218.44      71
# 167.64      32
# 220.98      30
# 121.92      20
# 165.10       8
# 223.52       8
# 228.60       6
# 226.06       4
# 162.56       4
# 160.02       3
# 154.94       2
# 157.48       2
# 134.62       1
# Name: count, dtype: int64

# %%
per_features = [
    'Min_per', 'TS_per', 'ORB_per', 'DRB_per','AST_per',
    'TO_per','twoP_per','TP_per','blk_per','stl_per']

for col in per_features:
    # Check if the maximum value is greater than 1, indicating a 0-100 range
    if df_clean[col].max() > 1:
        df_clean[col] = df_clean[col] / 100.0  # Convert to 0-1 range

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 16))
sns.heatmap(df_clean[num_cols].corr()[['drafted']], annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()

# %%
import seaborn as sns

corr_matrix = df_clean.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Matrix Heatmap')
plt.figure(figsize=(20, 15))
plt.show()

# %% [markdown]
# Remove highly correlated features

# %%
correlation_matrix = df_clean.corr().abs()

upper_tri = correlation_matrix.where(
    np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool)
)

threshold = 0.9

to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > threshold)]

df_clean = df_clean.drop(columns=to_drop)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 41 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GP         46618 non-null  int64
#  1   Min_per    46618 non-null  float64
#  2   Ortg       46618 non-null  float64
#  3   usg        46618 non-null  float64
#  4   eFG        46618 non-null  float64
#  5   ORB_per    46618 non-null  float64
#  6   DRB_per    46618 non-null  float64
#  7   AST_per    46618 non-null  float64
#  8   TO_per     46618 non-null  float64
#  9   FTM        46618 non-null  int64
#  10  FT_per     46618 non-null  float64
#  11  twoPM      46618 non-null  int64
#  12  twoP_per   46618 non-null  float64
#  13  TPM        46618 non-null  int64
#  14  TP_per     46618 non-null  float64
#  15  blk_per    46618 non-null  float64
#  16  stl_per    46618 non-null  float64
#  17  ftr        46618 non-null  float64
#  18  yr         46321 non-null  float64
#  19  ht         46289 non-null  float64
#  20  porpag     46618 non-null  float64
#  21  pfr        46618 non-null  float64
#  22  year       46618 non-null  int64
#  23  ast_tov    43151 non-null  float64
#  24  midmade    40860 non-null  float64
#  25  rim_ratio  38119 non-null  float64
#  26  mid_ratio  38050 non-null  float64
#  27  dunksmade  40860 non-null  float64
#  28  drtg       46576 non-null  float64
#  29  dporpag    46576 non-null  float64
#  30  bpm        46576 non-null  float64
#  31  obpm       46576 non-null  float64
#  32  dbpm       46576 non-null  float64
#  33  gbpm       46576 non-null  float64
#  34  dgbpm      46576 non-null  float64
#  35  oreb       46582 non-null  float64
#  36  dreb       46582 non-null  float64
#  37  ast        46582 non-null  float64
#  38  stl        46582 non-null  float64
#  39  blk        46582 non-null  float64
#  40  drafted    46618 non-null  float64
# dtypes: float64(36), int64(5)
# memory usage: 14.6 MB

# %%
missing_columns = df_clean.select_dtypes(include='number').columns[df_clean.isnull().any()]

train_medians = df_clean[missing_columns].median()

df_clean[missing_columns] = df_clean[missing_columns].fillna(train_medians)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 41 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GP         46618 non-null  int64
#  1   Min_per    46618 non-null  float64
#  2   Ortg       46618 non-null  float64
#  3   usg        46618 non-null  float64
#  4   eFG        46618 non-null  float64
#  5   ORB_per    46618 non-null  float64
#  6   DRB_per    46618 non-null  float64
#  7   AST_per    46618 non-null  float64
#  8   TO_per     46618 non-null  float64
#  9   FTM        46618 non-null  int64
#  10  FT_per     46618 non-null  float64
#  11  twoPM      46618 non-null  int64
#  12  twoP_per   46618 non-null  float64
#  13  TPM        46618 non-null  int64
#  14  TP_per     46618 non-null  float64
#  15  blk_per    46618 non-null  float64
#  16  stl_per    46618 non-null  float64
#  17  ftr        46618 non-null  float64
#  18  yr         46618 non-null  float64
#  19  ht         46618 non-null  float64
#  20  porpag     46618 non-null  float64
#  21  pfr        46618 non-null  float64
#  22  year       46618 non-null  int64
#  23  ast_tov    46618 non-null  float64
#  24  midmade    46618 non-null  float64
#  25  rim_ratio  46618 non-null  float64
#  26  mid_ratio  46618 non-null  float64
#  27  dunksmade  46618 non-null  float64
#  28  drtg       46618 non-null  float64
#  29  dporpag    46618 non-null  float64
#  30  bpm        46618 non-null  float64
#  31  obpm       46618 non-null  float64
#  32  dbpm       46618 non-null  float64
#  33  gbpm       46618 non-null  float64
#  34  dgbpm      46618 non-null  float64
#  35  oreb       46618 non-null  float64
#  36  dreb       46618 non-null  float64
#  37  ast        46618 non-null  float64
#  38  stl        46618 non-null  float64
#  39  blk        46618 non-null  float64
#  40  drafted    46618 non-null  float64
# dtypes: float64(36), int64(5)
# memory usage: 14.6 MB

# %%
from group_12_krml_adv_mla_2024.features.feature_thresholding import IQRThresholding

# %%
iqr_thresholding = IQRThresholding()

# %%
performance_var = [
    'Ortg','usg','eFG','ORB_per','DRB_per','AST_per','TO_per','FTM',
    'FT_per','twoPM','twoP_per','TPM','TP_per','blk_per','stl_per',
    'ftr','pfr','midmade','dunksmade','bpm','obpm','dbpm',
    'gbpm','dgbpm']

# %%
for col in performance_var:
    df_clean = iqr_thresholding.using_iqr(dataset='training', data=df_clean, col=col)
# Out:
# fth : {'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}]
# fth : {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}]
# fth : {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}]
# fth : {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}]
# fth : {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}]
# fth : {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}]
# fth : {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}, {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}]
# fth : {'FTM': {'lower_bound': -66.5, 'upper_bound': 121.5}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}, {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}, {'FTM': {'lower_bound': -66.5, 'upper_bound': 121.5}}]
# fth : {'FT_per': {'lower_bound': 0.125, 'upper_bound': 1.125}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}, {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}, {'FTM': {'lower_bound': -66.5, 'upper_bound': 121.5}}, {'FT_per': {'lower_bound': 0.125, 'upper_bound': 1.125}}]
# fth : {'twoPM': {'lower_bound': -85.0, 'upper_bound': 155.0}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}, {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}, {'FTM': {'lower_bound': -66.5, 'upper_bound': 121.5}}, {'FT_per': {'lower_bound': 0.125, 'upper_bound': 1.125}}, {'twoPM': {'lower_bound': -85.0, 'upper_bound': 155.0}}]
# fth : {'twoP_per': {'lower_bound': 0.14449999999999996, 'upper_bound': 0.7485}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}, {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}, {'FTM': {'lower_bound': -66.5, 'upper_bound': 121.5}}, {'FT_per': {'lower_bound': 0.125, 'upper_bound': 1.125}}, {'twoPM': {'lower_bound': -85.0, 'upper_bound': 155.0}}, {'twoP_per': {'lower_bound': 0.14449999999999996, 'upper_bound': 0.7485}}]
# fth : {'TPM': {'lower_bound': -36.0, 'upper_bound': 60.0}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}, {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}, {'FTM': {'lower_bound': -66.5, 'upper_bound': 121.5}}, {'FT_per': {'lower_bound': 0.125, 'upper_bound': 1.125}}, {'twoPM': {'lower_bound': -85.0, 'upper_bound': 155.0}}, {'twoP_per': {'lower_bound': 0.14449999999999996, 'upper_bound': 0.7485}}, {'TPM': {'lower_bound': -36.0, 'upper_bound': 60.0}}]
# fth : {'TP_per': {'lower_bound': -0.5355, 'upper_bound': 0.8925}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}, {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}, {'FTM': {'lower_bound': -66.5, 'upper_bound': 121.5}}, {'FT_per': {'lower_bound': 0.125, 'upper_bound': 1.125}}, {'twoPM': {'lower_bound': -85.0, 'upper_bound': 155.0}}, {'twoP_per': {'lower_bound': 0.14449999999999996, 'upper_bound': 0.7485}}, {'TPM': {'lower_bound': -36.0, 'upper_bound': 60.0}}, {'TP_per': {'lower_bound': -0.5355, 'upper_bound': 0.8925}}]
# fth : {'blk_per': {'lower_bound': -0.037500000000000006, 'upper_bound': 0.0625}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}, {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}, {'FTM': {'lower_bound': -66.5, 'upper_bound': 121.5}}, {'FT_per': {'lower_bound': 0.125, 'upper_bound': 1.125}}, {'twoPM': {'lower_bound': -85.0, 'upper_bound': 155.0}}, {'twoP_per': {'lower_bound': 0.14449999999999996, 'upper_bound': 0.7485}}, {'TPM': {'lower_bound': -36.0, 'upper_bound': 60.0}}, {'TP_per': {'lower_bound': -0.5355, 'upper_bound': 0.8925}}, {'blk_per': {'lower_bound': -0.037500000000000006, 'upper_bound': 0.0625}}]
# fth : {'stl_per': {'lower_bound': -0.010500000000000002, 'upper_bound': 0.04150000000000001}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}, {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}, {'FTM': {'lower_bound': -66.5, 'upper_bound': 121.5}}, {'FT_per': {'lower_bound': 0.125, 'upper_bound': 1.125}}, {'twoPM': {'lower_bound': -85.0, 'upper_bound': 155.0}}, {'twoP_per': {'lower_bound': 0.14449999999999996, 'upper_bound': 0.7485}}, {'TPM': {'lower_bound': -36.0, 'upper_bound': 60.0}}, {'TP_per': {'lower_bound': -0.5355, 'upper_bound': 0.8925}}, {'blk_per': {'lower_bound': -0.037500000000000006, 'upper_bound': 0.0625}}, {'stl_per': {'lower_bound': -0.010500000000000002, 'upper_bound': 0.04150000000000001}}]
# fth : {'ftr': {'lower_bound': -23.050000000000004, 'upper_bound': 91.75}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}, {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}, {'FTM': {'lower_bound': -66.5, 'upper_bound': 121.5}}, {'FT_per': {'lower_bound': 0.125, 'upper_bound': 1.125}}, {'twoPM': {'lower_bound': -85.0, 'upper_bound': 155.0}}, {'twoP_per': {'lower_bound': 0.14449999999999996, 'upper_bound': 0.7485}}, {'TPM': {'lower_bound': -36.0, 'upper_bound': 60.0}}, {'TP_per': {'lower_bound': -0.5355, 'upper_bound': 0.8925}}, {'blk_per': {'lower_bound': -0.037500000000000006, 'upper_bound': 0.0625}}, {'stl_per': {'lower_bound': -0.010500000000000002, 'upper_bound': 0.04150000000000001}}, {'ftr': {'lower_bound': -23.050000000000004, 'upper_bound': 91.75}}]
# fth : {'pfr': {'lower_bound': -0.8000000000000007, 'upper_bound': 8.8}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}, {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}, {'FTM': {'lower_bound': -66.5, 'upper_bound': 121.5}}, {'FT_per': {'lower_bound': 0.125, 'upper_bound': 1.125}}, {'twoPM': {'lower_bound': -85.0, 'upper_bound': 155.0}}, {'twoP_per': {'lower_bound': 0.14449999999999996, 'upper_bound': 0.7485}}, {'TPM': {'lower_bound': -36.0, 'upper_bound': 60.0}}, {'TP_per': {'lower_bound': -0.5355, 'upper_bound': 0.8925}}, {'blk_per': {'lower_bound': -0.037500000000000006, 'upper_bound': 0.0625}}, {'stl_per': {'lower_bound': -0.010500000000000002, 'upper_bound': 0.04150000000000001}}, {'ftr': {'lower_bound': -23.050000000000004, 'upper_bound': 91.75}}, {'pfr': {'lower_bound': -0.8000000000000007, 'upper_bound': 8.8}}]
# fth : {'midmade': {'lower_bound': -23.5, 'upper_bound': 44.5}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}, {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}, {'FTM': {'lower_bound': -66.5, 'upper_bound': 121.5}}, {'FT_per': {'lower_bound': 0.125, 'upper_bound': 1.125}}, {'twoPM': {'lower_bound': -85.0, 'upper_bound': 155.0}}, {'twoP_per': {'lower_bound': 0.14449999999999996, 'upper_bound': 0.7485}}, {'TPM': {'lower_bound': -36.0, 'upper_bound': 60.0}}, {'TP_per': {'lower_bound': -0.5355, 'upper_bound': 0.8925}}, {'blk_per': {'lower_bound': -0.037500000000000006, 'upper_bound': 0.0625}}, {'stl_per': {'lower_bound': -0.010500000000000002, 'upper_bound': 0.04150000000000001}}, {'ftr': {'lower_bound': -23.050000000000004, 'upper_bound': 91.75}}, {'pfr': {'lower_bound': -0.8000000000000007, 'upper_bound': 8.8}}, {'midmade': {'lower_bound': -23.5, 'upper_bound': 44.5}}]
# fth : {'dunksmade': {'lower_bound': -4.5, 'upper_bound': 7.5}}
# self. tfeath: [{'Ortg': {'lower_bound': 49.55000000000002, 'upper_bound': 141.14999999999998}}, {'usg': {'lower_bound': 3.799999999999999, 'upper_bound': 32.6}}, {'eFG': {'lower_bound': 20.5, 'upper_bound': 72.5}}, {'ORB_per': {'lower_bound': -0.07549999999999997, 'upper_bound': 0.17649999999999996}}, {'DRB_per': {'lower_bound': -0.028499999999999984, 'upper_bound': 0.27149999999999996}}, {'AST_per': {'lower_bound': -0.113, 'upper_bound': 0.311}}, {'TO_per': {'lower_bound': 0.001999999999999974, 'upper_bound': 0.394}}, {'FTM': {'lower_bound': -66.5, 'upper_bound': 121.5}}, {'FT_per': {'lower_bound': 0.125, 'upper_bound': 1.125}}, {'twoPM': {'lower_bound': -85.0, 'upper_bound': 155.0}}, {'twoP_per': {'lower_bound': 0.14449999999999996, 'upper_bound': 0.7485}}, {'TPM': {'lower_bound': -36.0, 'upper_bound': 60.0}}, {'TP_per': {'lower_bound': -0.5355, 'upper_bound': 0.8925}}, {'blk_per': {'lower_bound': -0.037500000000000006, 'upper_bound': 0.0625}}, {'stl_per': {'lower_bound': -0.010500000000000002, 'upper_bound': 0.04150000000000001}}, {'ftr': {'lower_bound': -23.050000000000004, 'upper_bound': 91.75}}, {'pfr': {'lower_bound': -0.8000000000000007, 'upper_bound': 8.8}}, {'midmade': {'lower_bound': -23.5, 'upper_bound': 44.5}
# %%
df_clean['drafted'].value_counts()
# Out:
# drafted
# 0.0    46174
# 1.0      444
# Name: count, dtype: int64

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 41 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GP         46618 non-null  int64
#  1   Min_per    46618 non-null  float64
#  2   Ortg       46618 non-null  float64
#  3   usg        46618 non-null  float64
#  4   eFG        46618 non-null  float64
#  5   ORB_per    46618 non-null  float64
#  6   DRB_per    46618 non-null  float64
#  7   AST_per    46618 non-null  float64
#  8   TO_per     46618 non-null  float64
#  9   FTM        46618 non-null  float64
#  10  FT_per     46618 non-null  float64
#  11  twoPM      46618 non-null  float64
#  12  twoP_per   46618 non-null  float64
#  13  TPM        46618 non-null  float64
#  14  TP_per     46618 non-null  float64
#  15  blk_per    46618 non-null  float64
#  16  stl_per    46618 non-null  float64
#  17  ftr        46618 non-null  float64
#  18  yr         46618 non-null  float64
#  19  ht         46618 non-null  float64
#  20  porpag     46618 non-null  float64
#  21  pfr        46618 non-null  float64
#  22  year       46618 non-null  int64
#  23  ast_tov    46618 non-null  float64
#  24  midmade    46618 non-null  float64
#  25  rim_ratio  46618 non-null  float64
#  26  mid_ratio  46618 non-null  float64
#  27  dunksmade  46618 non-null  float64
#  28  drtg       46618 non-null  float64
#  29  dporpag    46618 non-null  float64
#  30  bpm        46618 non-null  float64
#  31  obpm       46618 non-null  float64
#  32  dbpm       46618 non-null  float64
#  33  gbpm       46618 non-null  float64
#  34  dgbpm      46618 non-null  float64
#  35  oreb       46618 non-null  float64
#  36  dreb       46618 non-null  float64
#  37  ast        46618 non-null  float64
#  38  stl        46618 non-null  float64
#  39  blk        46618 non-null  float64
#  40  drafted    46618 non-null  float64
# dtypes: float64(39), int64(2)
# memory usage: 14.6 MB

# %%
unlabeled = ['ftr','pfr']
df_clean = df_clean.drop(columns=unlabeled)

# %%
df_cleaned = df_clean.copy()

# %%
df_cleaned
# Out:
#        GP  Min_per    Ortg   usg   eFG  ORB_per  DRB_per  AST_per  TO_per  \
# 0      26    0.295   97.30  16.6  42.5    0.016    0.046    0.158   0.163
# 1      34    0.609  108.30  14.9  52.4    0.038    0.063    0.136   0.198
# 2      27    0.720   96.20  21.8  45.7    0.021    0.080    0.147   0.159
# 3      30    0.445   97.70  16.0  53.6    0.041    0.094    0.137   0.238
# 4      33    0.562   96.50  22.0  52.8    0.083    0.186    0.082   0.227
# ...    ..      ...     ...   ...   ...      ...      ...      ...     ...
# 46613   1    0.001   49.55  20.0  20.5    0.000    0.000    0.000   0.002
# 46614   3    0.003   49.55  32.6  20.5    0.000    0.263    0.311   0.382
# 46615   1    0.003   49.55   3.8  20.5    0.000    0.000    0.000   0.002
# 46616   1    0.001   54.00  20.0  20.5    0.000    0.000    0.311   0.002
# 46617  32    0.707  108.30  19.8  50.8    0.029    0.106    0.043   0.126
#
#         FTM  FT_per  twoPM  twoP_per   TPM  TP_per  blk_per  stl_per   yr  \
# 46613 -15.628546 -5.937094  0.0000  0.0000  0.0000  0.0000  0.0000      0.0
# 46614 -15.628546 -5.937094  0.0000  0.3333  0.3333  0.3333  0.0000      0.0
# 46615 -11.561300 -5.937094  0.0000  0.0000  0.0000  0.0000  0.0000      0.0
# 46616 -10.257900 -5.937094  0.0000  0.0000  1.0000  0.0000  0.0000      0.0
# 46617   0.777853 -1.575910  0.8125  2.7188  0.6875  0.8125  0.3750      0.0
#
# [46618 rows x 39 columns]

# %% [markdown]
# ## Assess Baseline

# %%
y = df_cleaned.pop('drafted')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
df_scaled = scaler.fit_transform(df_cleaned)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 38 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GP         46618 non-null  int64
#  1   Min_per    46618 non-null  float64
#  2   Ortg       46618 non-null  float64
#  3   usg        46618 non-null  float64
#  4   eFG        46618 non-null  float64
#  5   ORB_per    46618 non-null  float64
#  6   DRB_per    46618 non-null  float64
#  7   AST_per    46618 non-null  float64
#  8   TO_per     46618 non-null  float64
#  9   FTM        46618 non-null  float64
#  10  FT_per     46618 non-null  float64
#  11  twoPM      46618 non-null  float64
#  12  twoP_per   46618 non-null  float64
#  13  TPM        46618 non-null  float64
#  14  TP_per     46618 non-null  float64
#  15  blk_per    46618 non-null  float64
#  16  stl_per    46618 non-null  float64
#  17  yr         46618 non-null  float64
#  18  ht         46618 non-null  float64
#  19  porpag     46618 non-null  float64
#  20  year       46618 non-null  int64
#  21  ast_tov    46618 non-null  float64
#  22  midmade    46618 non-null  float64
#  23  rim_ratio  46618 non-null  float64
#  24  mid_ratio  46618 non-null  float64
#  25  dunksmade  46618 non-null  float64
#  26  drtg       46618 non-null  float64
#  27  dporpag    46618 non-null  float64
#  28  bpm        46618 non-null  float64
#  29  obpm       46618 non-null  float64
#  30  dbpm       46618 non-null  float64
#  31  gbpm       46618 non-null  float64
#  32  dgbpm      46618 non-null  float64
#  33  oreb       46618 non-null  float64
#  34  dreb       46618 non-null  float64
#  35  ast        46618 non-null  float64
#  36  stl        46618 non-null  float64
#  37  blk        46618 non-null  float64
# dtypes: float64(36), int64(2)
# memory usage: 13.5 MB

# %%
from sklearn.model_selection import train_test_split

X_train, X_test,  y_train, y_test = train_test_split(df_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %%
from group_12_krml_adv_mla_2024.models.null import NullClassifier

# %%
base_model = NullClassifier()

# %%
y_base = base_model.fit_predict(y_train)

# %%
from group_12_krml_adv_mla_2024.models.performance import print_classifier_scores

print_classifier_scores(y_preds=y_base, y_actuals=y_train, average="weighted", set_name='Training')
# Out:
# Accuracy Training: 0.990481042526948
# F1 Score Training: 0.9857443247586095

# %%
print_classifier_scores(y_preds=base_model.predict(y_test), y_actuals=y_test, average="weighted", set_name='Testing')
# Out:
# Accuracy Testing: 0.9904547404547405
# F1 Score Testing: 0.9857049979093192

# %%
pred_value = y_train.mode()

# %%
y_base = np.full((len(y_train), 1), pred_value)

# %%
from sklearn.metrics import accuracy_score as acs
from sklearn.metrics import f1_score as f1s

# %%
print(acs(y_base, y_train))
print(f1s(y_base, y_train, average="weighted"))
# Out:
# 0.990481042526948
# 0.9952177602952864

# %% [markdown]
# ## Deep Learning

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (2.4.0)
# Requirement already satisfied: torchvision in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (0.19.0)
# Requirement already satisfied: filelock in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy<2 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from sympy->torch) (1.3.0)

# %%
# !pip install skorch
# Out:
# Requirement already satisfied: skorch in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from skorch) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from skorch) (1.5.1)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from skorch) (1.14.0)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from skorch) (0.9.0)
# Requirement already satisfied: tqdm>=4.14.0 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from skorch) (4.66.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from scikit-learn>=0.22.0->skorch) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from scikit-learn>=0.22.0->skorch) (3.5.0)
# Requirement already satisfied: colorama in c:\users\bert_\projects\adv_mla_2024\at1-kaggle-competition-group-12\.venv\lib\site-packages (from tqdm>=4.14.0->skorch) (0.4.6)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
class SimpleNN(nn.Module):
    def __init__(self, input_dim):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(128, 64)
        self.relu = nn.ReLU()
        self.fc3 = nn.Linear(64, 32)
        self.relu = nn.ReLU()
        self.fc4 = nn.Linear(32, 16)
        self.relu = nn.ReLU()
        self.fc5 = nn.Linear(16, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.fc3(x)
        x = self.relu(x)
        x = self.fc4(x)
        x = self.relu(x)
        x = self.fc5(x)
        x = self.sigmoid(x)
        return x.squeeze(1)  # Squeeze the output to have shape (batch_size,)

# %%
from skorch import NeuralNetClassifier

# Assuming X_train is your training data with shape (n_samples, n_features)
input_dim = X_train.shape[1]

# Define the Skorch NeuralNetClassifier
net = NeuralNetClassifier(
    module=SimpleNN,           # Your defined neural network class
    module__input_dim=input_dim,  # Pass the input dimension
    criterion = nn.BCELoss,      # Binary Cross-Entropy Loss for binary classification
    max_epochs=50,             # Number of epochs to train
    lr=0.0001,                   # Learning rate
    optimizer=torch.optim.Adam, # Optimizer
    optimizer__weight_decay=1e-5,  # L2 regularization (weight decay)
    iterator_train__shuffle=True, # Shuffle training data
)

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

# %%
net.fit(X_train, y_train)
# Out:
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.3784       0.9905        0.1095  0.6596
#       2        0.0740       0.9905        0.0549  0.6376
#       3        0.0482       0.9905        0.0416  0.6396
#       4        0.0382       0.9905        0.0349  0.6401
#       5        0.0329       0.9905        0.0316  0.6431
#       6        0.0299       0.9905        0.0296  0.6371
#       7        0.0281       0.9905        0.0286  0.6376
#       8        0.0270       0.9905        0.0279  0.6466
#       9        0.0260       0.9905        0.0275  0.6306
#      10        0.0252       0.9905        0.0272  0.6331
#      11        0.0247       0.9905        0.0267  0.6336
#      12        0.0242       0.9905        0.0265  0.6371
#      13        0.0237       0.9905        0.0263  0.6531
#      14        0.0234       0.9905        0.0259  0.6366
#      15        0.0230       0.9905        0.0258  0.6391
#      16        0.0227       0.9905        0.0259  0.6351
#      17        0.0223       0.9905        0.0256  0.6351
#      18        0.0221       0.9906        0.0258  0.6336
#      19        0.0216       0.9913        0.0255  0.6331
#      20        0.0216       0.9916        0.0250  0.6301
#      21        0.0212       0.9918        0.0254  0.6381
#      22        0.0209       0.9920        0.0250  0.6361
#      23        0.0207       0.9910        0.0251  0.6316
#      24        0.0204       0.9916        0.0247  0.6306
#      25        0.0201       0.9920        0.0248  0.6326
#      26        0.0199       0.9916        0.0249  0.6461
#      27        0.0197       0.9920        0.0247  0.6371
#      28        0.0193       0.9909        0.0249  0.6451
#      29        0.0195       0.9905        0.0248  0.6351
#      30        0.0190       0.9922        0.0254  0.6331
#      31        0.0189       0.9920        0.0250  0.6301
#      32        0.0185       0.9916        0.0244  0.6411
#      33        0.0184       0.9906        0.0250  0.6311
#      34        0.0181       0.9906        0.0247  0.6311
#      35        0.0179       0.9922        0.0255  0.6316
#      36        0.0178       0.9905        0.0246  0.6326
#      37        0.0174       0.9918        0.0247  0.6351
#      38        0.0173       0.9920        0.0249  0.6381
#      39        0.0170       0.9922        0.0259  0.6326
#      40        0.0170       0.9921        0.0251  0.6311
#      41        0.0168       0.9910        0.0253  0.6351
#      42        0.0164       0.9920        0.0257  0.6451
#      43        0.0165       0.9913        0.0257  0.6726
#      44        0.0161       0.9905        0.0253  0.6441
#      45        0.0160       0.9902        0.0257  0.6381
#      46        0.0158       0.9916        0.0263  0.6356
#      47        0.0159       0.9917        0.0262  0.6391
#      48        0.0155       0.9909        0.0261  0.6396
#      49        0.0153       0.9910        0.0267  0.6311
#      50        0.0153       0.9903        0.0266  0.6456
# <class 'skorch.classifier.NeuralNetClassifier'>[initialized](
#   module_=SimpleNN(
#     (fc1): Linear(in_features=38, out_features=128, bias=True)
#     (relu): ReLU()
#     (fc2): Linear(in_features=128, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=32, bias=True)
#     (fc4): Linear(in_features=32, out_features=16, bias=True)
#     (fc5): Linear(in_features=16, out_features=1, bias=True)
#     (sigmoid): Sigmoid()
#   ),
# )

# %%
y_train_preds = net.predict(X_train)
y_val_preds = net.predict(X_test)

# %%
print_classifier_scores(y_preds=y_train_preds, y_actuals=y_train, average="weighted", set_name='Training')
# Out:
# Accuracy Training: 0.9935646484689226
# F1 Score Training: 0.9932594825077644

# %%
print_classifier_scores(y_preds=y_val_preds, y_actuals=y_test, average="weighted", set_name='Testing')
# Out:
# Accuracy Testing: 0.9922779922779923
# F1 Score Testing: 0.9918473884343638

# %%
from group_12_krml_adv_mla_2024.models.performance import print_classifier_outcomes
print_classifier_outcomes(y_val_preds, y_test, average="weighted")
# Out:
# Accuracy: 0.9922779922779923
# F1 Score: 0.9918473884343638
# Confusion Matrix:
# [[9208   27]
#  [  45   44]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      9235
#          1.0       0.62      0.49      0.55        89
#
#     accuracy                           0.99      9324
#    macro avg       0.81      0.75      0.77      9324
# weighted avg       0.99      0.99      0.99      9324

# %%
from group_12_krml_adv_mla_2024.models.performance import compute_roc_curve

fpr, tpr, roc_auc = compute_roc_curve(net, X_test, y_test, positive_class=1)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# ROC AUC Score: 0.9869

# %% [markdown]
# ## Run on Test set and Produce CSV for Kaggle

# %%
test_df = pd.read_csv('../data/raw/test.csv')

# %%
test_df.isna().sum()
# Out:
# team                      0
# conf                      0
# GP                        0
# Min_per                   0
# Ortg                      0
# usg                       0
# eFG                       0
# TS_per                    0
# ORB_per                   0
# DRB_per                   0
# AST_per                   0
# TO_per                    0
# FTM                       0
# FTA                       0
# FT_per                    0
# twoPM                     0
# twoPA                     0
# twoP_per                  0
# TPM                       0
# TPA                       0
# TP_per                    0
# blk_per                   0
# stl_per                   0
# ftr                       0
# yr                        2
# ht                       13
# num                      96
# porpag                    0
# adjoe                     0
# pfr                       0
# year                      0
# type                      0
# Rec_Rank               3536
# ast_tov                 537
# rimmade                 248
# rimmade_rimmiss         248
# midmade                 248
# midmade_midmiss         248
# rim_ratio               646
# mid_ratio               697
# dunksmade               248
# dunksmiss_dunksmade     248
# dunks_ratio            2717
# pick                   4921
# drtg                      1
# adrtg                     1
# dporpag                   1
# stops                     1
# bpm                       1
# obpm                      1
# dbpm                      1
# gbpm                      1
# mp                        0
# ogbpm                     1
# dgbpm                     1
# oreb                      0
# dreb                      0
# treb                      0
# ast                       0
# stl                       0
# blk                       0
# pts                       0
# player_id                 0
# dtype: int64

# %%
per_features = [
    'Min_per', 'TS_per', 'ORB_per', 'DRB_per','AST_per',
    'TO_per','twoP_per','TP_per','blk_per','stl_per']

for col in per_features:
    # Check if the maximum value is greater than 1, indicating a 0-100 range
    if test_df[col].max() > 1:
       test_df[col] = test_df[col] / 100.0  # Convert to 0-1 range

# %%
test_df = test_df.drop(columns=columns_to_drop)
test_df = test_df.drop(columns=to_drop)
columns_to_keep = ['yr', 'ht']
cat_columns_to_drop = [col for col in cat_cols if col not in columns_to_keep]
test_df = test_df.drop(columns=cat_columns_to_drop)

# %%
test_df['yr'] = test_df['yr'].replace(['57.1', '42.9'], '0')
year_mapping = {'0': 0, 'Fr': 1, 'So': 2, 'Jr': 3, 'Sr': 4}
test_df['yr'] = test_df['yr'].map(year_mapping)
test_df = convert_height(test_df, 'ht')

# %%
test_df[missing_columns] = test_df[missing_columns].fillna(train_medians)

# %%
for col in performance_var:
    test_df = iqr_thresholding.using_iqr(dataset='testing', data=test_df, col=col)

# %%
test_df = test_df.drop(columns=unlabeled)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4970 entries, 0 to 4969
# Data columns (total 38 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GP         4970 non-null   int64
#  1   Min_per    4970 non-null   float64
#  2   Ortg       4970 non-null   float64
#  3   usg        4970 non-null   float64
#  4   eFG        4970 non-null   float64
#  5   ORB_per    4970 non-null   float64
#  6   DRB_per    4970 non-null   float64
#  7   AST_per    4970 non-null   float64
#  8   TO_per     4970 non-null   float64
#  9   FTM        4970 non-null   int64
#  10  FT_per     4970 non-null   float64
#  11  twoPM      4970 non-null   int64
#  12  twoP_per   4970 non-null   float64
#  13  TPM        4970 non-null   int64
#  14  TP_per     4970 non-null   float64
#  15  blk_per    4970 non-null   float64
#  16  stl_per    4970 non-null   float64
#  17  yr         4970 non-null   float64
#  18  ht         4970 non-null   float64
#  19  porpag     4970 non-null   float64
#  20  year       4970 non-null   int64
#  21  ast_tov    4970 non-null   float64
#  22  midmade    4970 non-null   float64
#  23  rim_ratio  4970 non-null   float64
#  24  mid_ratio  4970 non-null   float64
#  25  dunksmade  4970 non-null   float64
#  26  drtg       4970 non-null   float64
#  27  dporpag    4970 non-null   float64
#  28  bpm        4970 non-null   float64
#  29  obpm       4970 non-null   float64
#  30  dbpm       4970 non-null   float64
#  31  gbpm       4970 non-null   float64
#  32  dgbpm      4970 non-null   float64
#  33  oreb       4970 non-null   float64
#  34  dreb       4970 non-null   float64
#  35  ast        4970 non-null   float64
#  36  stl        4970 non-null   float64
#  37  blk        4970 non-null   float64
# dtypes: float64(33), int64(5)
# memory usage: 1.4 MB

# %%
scaled_test_df = scaler.fit_transform(test_df)

# %%
scaled_test_df = scaled_test_df.astype('float32')

# %%
y_test_prob = net.predict_proba(scaled_test_df)[:,1]

# %%
t_df = pd.read_csv('../data/raw/test.csv')
results_df = pd.DataFrame({'player_id':t_df['player_id'], 'drafted':y_test_prob})

# %%
results_df.to_csv('../data/external/NNClassifier.csv', index=False)
