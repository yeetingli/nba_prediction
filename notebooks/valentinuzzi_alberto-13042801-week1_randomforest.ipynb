# %% [markdown]
# ## Data Exploration and Cleaning

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/raw/train.csv')
# Out:
# C:\Users\bert_\AppData\Local\Temp\ipykernel_6248\4229903785.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw/train.csv')

# %%
df.head()
# Out:
#             team conf  GP  Min_per   Ortg   usg   eFG  TS_per  ORB_per  \
# 0  South Alabama   SB  26     29.5   97.3  16.6  42.5   44.43      1.6
# 1       Utah St.  WAC  34     60.9  108.3  14.9  52.4   54.48      3.8
# 2  South Florida   BE  27     72.0   96.2  21.8  45.7   47.98      2.1
# 3     Pepperdine  WCC  30     44.5   97.7  16.0  53.6   53.69      4.1
# 4        Pacific   BW  33     56.2   96.5  22.0  52.8   54.31      8.3
#
#    DRB_per  AST_per  TO_per  FTM  FTA  FT_per  twoPM  twoPA  twoP_per  TPM  \
# 0      4.6     15.8    16.3   10   14   0.714     26     68     0.382   13
# 1      6.3     13.6    19.8   30   45   0.667     56    113     0.496   20
# 2      8.0     14.7    15.9   45   67   0.672     67    157     0.427   50
# 3      9.4     13.7    23.8   14   27   0.519     25     63     0.397   28
# 4     18.6      8.2    22.7   64  114   0.561     93    176     0.528    0
#
#    TPA  TP_per  blk_per  stl_per   ftr  yr     ht  num    porpag     adjoe  \
# ...

# %%
pd.options.display.max_columns=300
pd.options.display.max_rows=300

# %%
df.shape
# Out:
# (46618, 64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 64 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   team                 46618 non-null  object
#  1   conf                 46618 non-null  object
#  2   GP                   46618 non-null  int64
#  3   Min_per              46618 non-null  float64
#  4   Ortg                 46618 non-null  float64
#  5   usg                  46618 non-null  float64
#  6   eFG                  46618 non-null  float64
#  7   TS_per               46618 non-null  float64
#  8   ORB_per              46618 non-null  float64
#  9   DRB_per              46618 non-null  float64
#  10  AST_per              46618 non-null  float64
#  11  TO_per               46618 non-null  float64
#  12  FTM                  46618 non-null  int64
#  13  FTA                  46618 non-null  int64
#  14  FT_per               46618 non-null  float64
# ...

# %%
df.describe(include='all')
# Out:
#          team   conf            GP       Min_per          Ortg           usg  \
# count   46618  46618  46618.000000  46618.000000  46618.000000  46618.000000
# unique    355     36           NaN           NaN           NaN           NaN
# top      Army    A10           NaN           NaN           NaN           NaN
# freq      176   1880           NaN           NaN           NaN           NaN
# mean      NaN    NaN     23.542988     37.339013     91.784360     18.164578
# std       NaN    NaN     10.076829     28.019801     30.235568      6.181982
# min       NaN    NaN      1.000000      0.000000      0.000000      0.000000
# 25%       NaN    NaN     17.000000      9.600000     83.900000     14.600000
# 50%       NaN    NaN     28.000000     35.900000     97.000000     18.100000
# 75%       NaN    NaN     31.000000     62.200000    106.800000     21.800000
# max       NaN    NaN     41.000000     98.000000    834.000000     50.000000
#
# ...

# %%
df.isna().sum()
# Out:
# team                       0
# conf                       0
# GP                         0
# Min_per                    0
# Ortg                       0
# usg                        0
# eFG                        0
# TS_per                     0
# ORB_per                    0
# DRB_per                    0
# AST_per                    0
# TO_per                     0
# FTM                        0
# FTA                        0
# FT_per                     0
# twoPM                      0
# twoPA                      0
# twoP_per                   0
# TPM                        0
# TPA                        0
# TP_per                     0
# blk_per                    0
# stl_per                    0
# ftr                        0
# yr                       292
# ht                        64
# num                     4679
# porpag                     0
# adjoe                      0
# pfr                        0
# year                       0
# type                       0
# ...

# %%
df_clean = df.copy()

# %%
threshold = 0.2 * len(df)

# %%
columns_to_drop = df.columns[df.isnull().sum() > threshold]

# %%
df_clean = df_clean.drop(columns=columns_to_drop)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 61 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   team                 46618 non-null  object
#  1   conf                 46618 non-null  object
#  2   GP                   46618 non-null  int64
#  3   Min_per              46618 non-null  float64
#  4   Ortg                 46618 non-null  float64
#  5   usg                  46618 non-null  float64
#  6   eFG                  46618 non-null  float64
#  7   TS_per               46618 non-null  float64
#  8   ORB_per              46618 non-null  float64
#  9   DRB_per              46618 non-null  float64
#  10  AST_per              46618 non-null  float64
#  11  TO_per               46618 non-null  float64
#  12  FTM                  46618 non-null  int64
#  13  FTA                  46618 non-null  int64
#  14  FT_per               46618 non-null  float64
# ...

# %%
num_cols = df_clean.select_dtypes(include=['float64', 'int64']).columns
for col in num_cols:
    df_clean[col] = df_clean[col].fillna(df_clean[col].median())

# %%
cat_cols = df_clean.select_dtypes(include=['object']).columns
df_clean = df_clean.drop(columns=cat_cols)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 54 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GP                   46618 non-null  int64
#  1   Min_per              46618 non-null  float64
#  2   Ortg                 46618 non-null  float64
#  3   usg                  46618 non-null  float64
#  4   eFG                  46618 non-null  float64
#  5   TS_per               46618 non-null  float64
#  6   ORB_per              46618 non-null  float64
#  7   DRB_per              46618 non-null  float64
#  8   AST_per              46618 non-null  float64
#  9   TO_per               46618 non-null  float64
#  10  FTM                  46618 non-null  int64
#  11  FTA                  46618 non-null  int64
#  12  FT_per               46618 non-null  float64
#  13  twoPM                46618 non-null  int64
#  14  twoPA                46618 non-null  int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 16))
sns.heatmap(df_clean[num_cols].corr()[['drafted']], annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()

# %%
import seaborn as sns

corr_matrix = df_clean.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Matrix Heatmap')
plt.figure(figsize=(20, 15))
plt.show()

# %% [markdown]
# Dropping highly correlated features

# %%
correlation_matrix = df_clean.corr().abs()

upper_tri = correlation_matrix.where(
    np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool)
)

threshold = 0.9

to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > threshold)]

df_clean = df_clean.drop(columns=to_drop)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46618 entries, 0 to 46617
# Data columns (total 40 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GP         46618 non-null  int64
#  1   Min_per    46618 non-null  float64
#  2   Ortg       46618 non-null  float64
#  3   usg        46618 non-null  float64
#  4   eFG        46618 non-null  float64
#  5   ORB_per    46618 non-null  float64
#  6   DRB_per    46618 non-null  float64
#  7   AST_per    46618 non-null  float64
#  8   TO_per     46618 non-null  float64
#  9   FTM        46618 non-null  int64
#  10  FT_per     46618 non-null  float64
#  11  twoPM      46618 non-null  int64
#  12  twoP_per   46618 non-null  float64
#  13  TPM        46618 non-null  int64
#  14  TP_per     46618 non-null  float64
#  15  blk_per    46618 non-null  float64
#  16  stl_per    46618 non-null  float64
#  17  ftr        46618 non-null  float64
#  18  porpag     46618 non-null  float64
# ...

# %%
df_cleaned = df_clean.copy()

# %% [markdown]
# ## Assess Baseline

# %%
y = df_cleaned.pop('drafted')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
df_scaled = scaler.fit_transform(df_cleaned)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test,  y_train, y_test = train_test_split(df_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %%
pred_value = y_train.mode()

# %%
y_base = np.full((len(y_train), 1), pred_value)

# %%
from sklearn.metrics import accuracy_score as acs
from sklearn.metrics import f1_score as f1s

# %%
print(acs(y_base, y_train))
print(f1s(y_base, y_train, average="weighted"))
# Out:
# 0.990481042526948
# 0.9952177602952864

# %% [markdown]
# ## Initial Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_train_preds = rf_classifier.predict(X_train)
y_val_preds = rf_classifier.predict(X_test)

# %%
accuracy = acs(y_test, y_val_preds)
conf_matrix = confusion_matrix(y_test, y_val_preds)
report = classification_report(y_test, y_val_preds)

print(f"Accuracy: {accuracy:.4f}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.9922
# Confusion Matrix:
# [[9231    4]
#  [  69   20]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      9235
#          1.0       0.83      0.22      0.35        89
#
#     accuracy                           0.99      9324
#    macro avg       0.91      0.61      0.68      9324
# weighted avg       0.99      0.99      0.99      9324

# %%
print(acs(y_train_preds, y_train))
print(f1s(y_train_preds, y_train, average="weighted"))
# Out:
# 1.0
# 1.0

# %%
print(acs(y_val_preds, y_test))
print(f1s(y_val_preds, y_test, average="weighted"))
# Out:
# 0.9921707421707422
# 0.9944087917355426

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

# Get the probability scores for the test set
y_prob = rf_classifier.predict_proba(X_test)[:, 1]  # Probability estimates for the positive class

# Compute the ROC AUC score
roc_auc = roc_auc_score(y_test, y_prob)
print(f"ROC AUC Score: {roc_auc:.4f}")

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# ROC AUC Score: 0.9641

# %% [markdown]
# ## Grid Search using stratified Kfold for Hyperparamater Tuning

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold

rfgs = RandomForestClassifier(random_state=42)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
param_grid = {
    'n_estimators': [100, 200, 500],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5]
}

# %%
grid_search = GridSearchCV(
    estimator=rfgs,
    param_grid=param_grid,
    scoring='roc_auc',  # Optimize for ROC AUC
    cv=skf,             # Use StratifiedKFold for cross-validation
    n_jobs=-1,          # Use all available CPU cores
    verbose=2           # Verbosity level
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 5],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 500]},
#              scoring='roc_auc', verbose=2)

# %%
print("Best hyperparameters:", grid_search.best_params_)
print("Best ROC AUC score:", grid_search.best_score_)
# Out:
# Best hyperparameters: {'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
# Best ROC AUC score: 0.9822163999590057

# %% [markdown]
# ## Random Forest with GridSearch Hyperparameters

# %%
rff = RandomForestClassifier(n_estimators=500, max_depth=None, min_samples_leaf=5, min_samples_split=2, random_state=42)

# %%
rff.fit(X_train,y_train)
# Out:
# RandomForestClassifier(min_samples_leaf=5, n_estimators=500, random_state=42)

# %%
y_train_preds = rff.predict(X_train)
y_val_preds = rff.predict(X_test)

# %%
accuracy = acs(y_test, y_val_preds)
conf_matrix = confusion_matrix(y_test, y_val_preds)
report = classification_report(y_test, y_val_preds)

print(f"Accuracy: {accuracy:.4f}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.9921
# Confusion Matrix:
# [[9232    3]
#  [  71   18]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      9235
#          1.0       0.86      0.20      0.33        89
#
#     accuracy                           0.99      9324
#    macro avg       0.92      0.60      0.66      9324
# weighted avg       0.99      0.99      0.99      9324

# %%
print(acs(y_train_preds, y_train))
print(f1s(y_train_preds, y_train, average="weighted"))
# Out:
# 0.994556765163297
# 0.9956093400622271

# %%
print(acs(y_val_preds, y_test))
print(f1s(y_val_preds, y_test, average="weighted"))
# Out:
# 0.9920634920634921
# 0.9945020384010566

# %%
# Get the probability scores for the test set
y_prob = rff.predict_proba(X_test)[:, 1]  # Probability estimates for the positive class

# Compute the ROC AUC score
roc_auc = roc_auc_score(y_test, y_prob)
print(f"ROC AUC Score: {roc_auc:.4f}")

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# ROC AUC Score: 0.9756

# %% [markdown]
# ## Run on Test set and Produce CSV for Kaggle

# %%
test_df = pd.read_csv('../data/raw/test.csv')

# %%
test_df.isna().sum()
# Out:
# team                      0
# conf                      0
# GP                        0
# Min_per                   0
# Ortg                      0
# usg                       0
# eFG                       0
# TS_per                    0
# ORB_per                   0
# DRB_per                   0
# AST_per                   0
# TO_per                    0
# FTM                       0
# FTA                       0
# FT_per                    0
# twoPM                     0
# twoPA                     0
# twoP_per                  0
# TPM                       0
# TPA                       0
# TP_per                    0
# blk_per                   0
# stl_per                   0
# ftr                       0
# yr                        2
# ht                       13
# num                      96
# porpag                    0
# adjoe                     0
# pfr                       0
# year                      0
# type                      0
# Rec_Rank               3536
# ...

# %%
test_df = test_df.drop(columns=columns_to_drop)
test_df = test_df.drop(columns=to_drop)
test_df = test_df.drop(columns=cat_cols)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4970 entries, 0 to 4969
# Data columns (total 39 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GP         4970 non-null   int64
#  1   Min_per    4970 non-null   float64
#  2   Ortg       4970 non-null   float64
#  3   usg        4970 non-null   float64
#  4   eFG        4970 non-null   float64
#  5   ORB_per    4970 non-null   float64
#  6   DRB_per    4970 non-null   float64
#  7   AST_per    4970 non-null   float64
#  8   TO_per     4970 non-null   float64
#  9   FTM        4970 non-null   int64
#  10  FT_per     4970 non-null   float64
#  11  twoPM      4970 non-null   int64
#  12  twoP_per   4970 non-null   float64
#  13  TPM        4970 non-null   int64
#  14  TP_per     4970 non-null   float64
#  15  blk_per    4970 non-null   float64
#  16  stl_per    4970 non-null   float64
#  17  ftr        4970 non-null   float64
#  18  porpag     4970 non-null   float64
# ...

# %%
n_cols = df_cleaned.select_dtypes(include=['float64', 'int64']).columns

if 'drafted' in n_cols:
    n_cols = n_cols.drop('drafted')

for col in n_cols:
    median_value = df_cleaned[col].median()
    test_df[col] = test_df[col].fillna(median_value)

# %%
scaled_test_df = scaler.fit_transform(test_df)

# %%
y_test_prob = rff.predict_proba(scaled_test_df)[:,1]

# %%
t_df = pd.read_csv('../data/raw/test.csv')
results_df = pd.DataFrame({'player_id':t_df['player_id'], 'drafted':y_test_prob})

# %%
results_df.to_csv('../data/external/RandomForest.csv', index=False)
